# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from matplotlib.pyplot import figure

# %%
# Data has been read from different batches of data
# Data files for random dst and origin pincode
df=pd.read_csv("DataGen/dtdcData/0_1000_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])
df1=pd.read_csv("DataGen/dtdcData/0_1000_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])
df2=pd.read_csv("DataGen/dtdcData/1001_3000_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])
df3=pd.read_csv("DataGen/dtdcData2/3001_13000_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])

# Data files for interstate pincodes
df4=pd.read_csv("DataGen/dtdcData3/0_200_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])
df5=pd.read_csv("DataGen/dtdcData3/201_400_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])
df6=pd.read_csv("DataGen/dtdcData3/401_600_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])

# %%
df1.loc[df1['org_pin'] == '600032']
# Out:
#      org_pin dst_pin   dst_state po_del dtdc_del         box    len    wid  \
# 0     600032  686503      KERALA   True     true  AmazonBox3  22.86  15.24
# 1     600032  686503      KERALA   True     true  AmazonBox3  22.86  15.24
# 2     600032  686503      KERALA   True     true  AmazonBox3  22.86  15.24
# 6     600032  686503      KERALA   True     true  AmazonBox3  22.86  15.24
# 140   600032  620002   TAMILNADU  False     true  CustomBox1   17.7   10.1
# 141   600032  620002   TAMILNADU  False     true  CustomBox1   17.7   10.1
# 142   600032  620002   TAMILNADU  False     true  CustomBox1   17.7   10.1
# 143   600032  620002   TAMILNADU  False     true  CustomBox1   17.7   10.1
# 148   600032  620002   TAMILNADU  False     true  CustomBox1   17.7   10.1
# 1756  600032  770046      ODISHA   True     true  CustomBox7     30     30
# 1757  600032  770046      ODISHA   True     true  CustomBox7     30     30
# 1758  600032  770046      ODISHA   True     true  CustomBox7     30     30
# 1762  600032  770046      ODISHA   True     true  CustomBox7     30     30
# 2196  600032  140417      PUNJAB   True     true     DHLBox6   41.7   35.9
# 2197  600032  140417      PUNJAB   True     true     DHLBox6   41.7   35.9
# 2200  600032  140417      PUNJAB   True     true     DHLBox6   41.7   35.9
# 2984  600032  641025   TAMILNADU  False     true  CustomBox4     22   11.5
# 2985  600032  641025   TAMILNADU  False     true  CustomBox4     22   11.5
# 2986  600032  641025   TAMILNADU  False     true  CustomBox4     22   11.5
# 2987  600032  641025   TAMILNADU  False     true  CustomBox4     22   11.5
# 2992  600032  641025   TAMILNADU  False     true  CustomBox4     22   11.5
# 3492  600032  734203  WESTBENGAL  False     true  CustomBox4     22   11.5
# 3692  600032  763008      ODISHA   True     true     DHLBox5     34     33
# 3693  600032  763008      ODISHA   True     true     DHLBox5     34     33
# 3696  600032  763008      ODISHA   True     true     DHLBox5     34     33
# 3766  600032  695029      KERALA   True     true  CustomBox4     22   11.5
# 3767  600032  695029      KERALA   True     true  CustomBox4     22   11.5
# 3768  600032  695029      KERALA   True     true  CustomBox4     22   11.5
# 3772  600032  695029      KERALA   True     true  CustomBox4     22   11.5
#
#        dep  vol_wt act_wt obj_cost shipper               service  \
# 0     7.62    0.53   1273    20581    DTDC               PREMIUM
# 1     7.62    0.53   1273    20581    DTDC             STD EXP-A
# 2     7.62    0.53   1273    20581    DTDC             AIR CARGO
# 6     7.62    0.53   1273    20581    DTDC        GROUND EXPRESS
# 140   10.1   0.361    187    19663    DTDC  PRIME TIME PLUS 1400
# 141   10.1   0.361    187    19663    DTDC               PREMIUM
# 142   10.1   0.361    187    19663    DTDC             STD EXP-A
# 143   10.1   0.361    187    19663    DTDC             AIR CARGO
# 148   10.1   0.361    187    19663    DTDC        GROUND EXPRESS
# 1756    10     1.8   1216     7547    DTDC               PREMIUM
# 1757    10     1.8   1216     7547    DTDC             STD EXP-A
# 1758    10     1.8   1216     7547    DTDC             AIR CARGO
# 1762    10     1.8   1216     7547    DTDC        GROUND EXPRESS
# 2196  36.9  11.048   9905    15856    DTDC               PREMIUM
# 2197  36.9  11.048   9905    15856    DTDC             AIR CARGO
# 2200  36.9  11.048   9905    15856    DTDC        GROUND EXPRESS
# 2984   7.5  0.3795    750    17991    DTDC  PRIME TIME PLUS 1400
# 2985   7.5  0.3795    750    17991    DTDC               PREMIUM
# 2986   7.5  0.3795    750    17991    DTDC             STD EXP-A
# 2987   7.5  0.3795    750    17991    DTDC             AIR CARGO
# 2992   7.5  0.3795    750    17991    DTDC        GROUND EXPRESS
# 3492   7.5  0.3795    196     9588    DTDC               PREMIUM
# 3692    35   7.854   5602     3230    DTDC               PREMIUM
# 3693    35   7.854   5602     3230    DTDC             AIR CARGO
# 3696    35   7.854   5602     3230    DTDC        GROUND EXPRESS
# 3766   7.5  0.3795    465    12242    DTDC               PREMIUM
# 3767   7.5  0.3795    465    12242    DTDC             STD EXP-A
# 3768   7.5  0.3795    465    12242    DTDC             AIR CARGO
# 3772   7.5  0.3795    465    12242    DTDC        GROUND EXPRESS
#
#                          period price add_price price_risk_sur  \
# 0                       4 Day/s   565         0           1051
# 1                   4 - 5 Day/s   240         0            726
# 2                   4 - 5 Day/s   360         0            846
# 6                   4 - 5 Day/s   240         0            726
# 140   Next Business Day by 2 PM   245         0            709
# 141                     1 Day/s   220         0            684
# 142                 2 - 3 Day/s   100         0            564
# 143                 2 - 3 Day/s   270         0            734
# 148                 2 - 3 Day/s   195         0            659
# 1756                    5 Day/s  1115         0           1293
# 1757                5 - 6 Day/s   595         0            773
# 1758                5 - 6 Day/s   600         0            778
# 1762                6 - 7 Day/s   625         0            803
# 2196                    4 Day/s  4620         0           4994
# 2197                4 - 5 Day/s  2400         0           2774
# 2200                6 - 7 Day/s  1500         0           1874
# 2984  Next Business Day by 2 PM   355         0            780
# 2985                    1 Day/s   305         0            730
# 2986                2 - 3 Day/s   150         0            575
# 2987                2 - 3 Day/s   270         0            695
# 2992                1 - 2 Day/s   195         0            620
# 3492                    4 Day/s   380         0            606
# 3692                    5 Day/s  4055         0           4131
# 3693                5 - 6 Day/s  1600         0           1676
# 3696                6 - 7 Day/s  1125         0           1201
# 3766                    2 Day/s   305         0            594
# 3767                3 - 4 Day/s   120         0            409
# 3768                3 - 4 Day/s   360         0            649
# 3772                3 - 4 Day/s   240         0            529
#
#      price_carr_risk_sur price_own_risk_sur price_with_ins gstPer basePrice  \
# 0                   1051                614           1462     18       565
# 1                    726                289           1137     18       240
# 2                    846                409           1257     18       360
# 6                    726                289           1137     18       240
# 140                  709                291           1102     18       245
# 141                  684                266           1077     18       220
# 142                  564                146            957     18       100
# 143                  734                316           1127     18       270
# 148                  659                241           1052     18       195
# 1756                1293               1145           1444     18      1115
# 1757                 773                625            924     18       595
# 1758                 778                630            929     18       600
# 1762                 803                655            954     18       625
# 2196                4994               4657           5311     18      4620
# 2197                2774               2437           3091     18      2400
# 2200                1874               1537           2191     18      1500
# 2984                 780                397           1139     18       355
# 2985                 730                347           1089     18       305
# 2986                 575                192            934     18       150
# 2987                 695                312           1054     18       270
# 2992                 620                237            979     18       195
# 3492                 606                410            798     18       380
# 3692                4131               4085           4196     18      4055
# 3693                1676               1630           1741     18      1600
# 3696                1201               1155           1266     18      1125
# 3766                 594                335            839     18       305
# 3767                 409                150            654     18       120
# 3768                 649                390            894     18       360
# 3772                 529                270            774     18       240
#
#       gst gst_risk_sur gst_carr_risk_sur gst_own_risk_sur  edd charge_wt
# 0      86          160               160               94  NaN      1273
# 1      37          111               111               44  NaN      1273
# 2      55          129               129               62  NaN      1273
# 6      37          111               111               44  NaN      1273
# 140    37          108               108               44  NaN       362
# 141    34          104               104               41  NaN       362
# 142    15           86                86               22  NaN       362
# 143    41          112               112               48  NaN       362
# 148    30          101               101               37  NaN       381
# 1756  170          197               197              175  NaN      1800
# 1757   91          118               118               95  NaN      1800
# 1758   92          119               119               96  NaN      1800
# 1762   95          123               123              100  NaN      1895
# 2196  705          762               762              710  NaN     11049
# 2197  366          423               423              372  NaN     11049
# 2200  229          286               286              235  NaN     11630
# 2984   54          119               119               61  NaN       750
# 2985   47          111               111               53  NaN       750
# 2986   23           88                88               29  NaN       750
# 2987   41          106               106               48  NaN       750
# 2992   30           95                95               36  NaN       750
# 3492   58           92                92               62  NaN       380
# 3692  619          630               630              623  NaN      7854
# 3693  244          256               256              249  NaN      7854
# 3696  172          183               183              176  NaN      8268
# 3766   47           91                91               51  NaN       465
# 3767   18           62                62               23  NaN       465
# 3768   55           99                99               59  NaN       465
# 3772   37           81                81               41  NaN       465

# %%
df1.sample(frac=1)
# Out:
#      org_pin dst_pin        dst_state po_del dtdc_del         box    len  \
# 1215  110070  571108        KARNATAKA   True     true     DHLBox7   48.1
# 628   400102  518543    ANDHRAPRADESH  False     true  AmazonBox2  10.16
# 2104  190001  577181        KARNATAKA   True     true     DHLBox8     55
# 2346  175131  400702      MAHARASHTRA  False     true  CustomBox5     21
# 3719  160017  192301  JAMMUANDKASHMIR  False     true     DHLBox7   48.1
# ...      ...     ...              ...    ...      ...         ...    ...
# 2163  682304  735224       WESTBENGAL   True     true  CustomBox1   17.7
# 1953  175121  722207       WESTBENGAL  False     true     DHLBox2     34
# 2374  562157  335512        RAJASTHAN  False     true  AmazonBox5   27.7
# 482   201301  246722     UTTARPRADESH   True     true     DHLBox7   48.1
# 2250  737102  625006        TAMILNADU  False     true  CustomBox1   17.7
#
#         wid   dep  vol_wt act_wt obj_cost shipper         service  \
# 1215  40.40  38.9  15.118  10285     4554    DTDC       AIR CARGO
# 628   10.16  3.81    0.07    728    10868    DTDC       STD EXP-A
# 2104     45    41  20.295   9594    17911    DTDC         PREMIUM
# 2346   10.1  15.5   0.657    696    22772    DTDC         PREMIUM
# 3719  40.40  38.9  15.118   8574    21201    DTDC       AIR CARGO
# ...     ...   ...     ...    ...      ...     ...             ...
# 2163   10.1  10.1   0.361    368    21095    DTDC  GROUND EXPRESS
# 1953     33     6   1.347   1003     8885    DTDC  GROUND EXPRESS
# 2374   20.9  22.5   2.605   1749     9656    DTDC       STD EXP-A
# 482   40.40  38.9  15.118  16109     5451    DTDC  GROUND EXPRESS
# 2250   10.1  10.1   0.361    694    12978    DTDC       STD EXP-A
#
#             period price add_price price_risk_sur price_carr_risk_sur  \
# 1215   4 - 5 Day/s  3200         0           3307                3307
# 628    3 - 4 Day/s   325         0            581                 581
# 2104       4 Day/s  8085         0           8508                8508
# 2346       4 Day/s   570         0           1107                1107
# 3719   6 - 7 Day/s  1920         0           2420                2420
# ...            ...   ...       ...            ...                 ...
# 2163  9 - 10 Day/s   580         0           1082                1082
# 1953  9 - 10 Day/s   625         0            835                 835
# 2374   4 - 5 Day/s   865         0           1093                1093
# 482    4 - 5 Day/s  1105         0           1234                1234
# 2250   5 - 6 Day/s   325         0            631                 631
#
#      price_own_risk_sur price_with_ins gstPer basePrice   gst gst_risk_sur  \
# 1215               3230           3399     18      3200   488          505
# 628                 355            799     18       325    50           89
# 2104               8127           8866     18      8085  1233         1298
# 2346                624           1563     18       570    87          169
# 3719               1970           2844     18      1920   293          369
# ...                 ...            ...    ...       ...   ...          ...
# 2163                630           1504     19       580    93          173
# 1953                655           1012     18       625    95          127
# 2374                895           1286     18       865   132          167
# 482                1135           1343     18      1105   169          188
# 2250                356            891     18       325    50           96
#
#      gst_carr_risk_sur gst_own_risk_sur  edd charge_wt
# 1215               505              493  NaN     15119
# 628                 89               54  NaN       728
# 2104              1298             1240  NaN     20295
# 2346               169               95  NaN       696
# 3719               369              301  NaN     15119
# ...                ...              ...  ...       ...
# 2163               173              101  NaN       381
# 1953               127              100  NaN      1418
# 2374               167              136  NaN      2606
# 482                188              173  NaN     16109
# 2250                96               54  NaN       694
#
# [4338 rows x 29 columns]

# %%
# Get all Pincode data for domestic model
pincode_data=pd.read_csv("DataGen/india_pincode_geo_metro.csv")

# %%
pincode_data=pincode_data.drop(columns=['id'])

# %%
# Dropping duplicate rows
df1=df1.drop_duplicates()
df2=df2.drop_duplicates()
df3=df3.drop_duplicates()
df4=df4.drop_duplicates()
df5=df5.drop_duplicates()
df6=df6.drop_duplicates()

# %%
df1
# Out:
#      org_pin dst_pin dst_state po_del dtdc_del         box    len    wid  \
# 0     600032  686503    KERALA   True     true  AmazonBox3  22.86  15.24
# 1     600032  686503    KERALA   True     true  AmazonBox3  22.86  15.24
# 2     600032  686503    KERALA   True     true  AmazonBox3  22.86  15.24
# 6     600032  686503    KERALA   True     true  AmazonBox3  22.86  15.24
# 8     171001  394325   GUJARAT   True     true  CustomBox1   17.7   10.1
# ...      ...     ...       ...    ...      ...         ...    ...    ...
# 4328  160017  782123     ASSAM   True     true  AmazonBox5   27.7   20.9
# 4330  131001  689573    KERALA   True     true  CustomBox5     21   10.1
# 4332  131001  689573    KERALA   True     true  CustomBox5     21   10.1
# 4334  131001  689573    KERALA   True     true  CustomBox5     21   10.1
# 4336  131001  689573    KERALA   True     true  CustomBox5     21   10.1
#
#        dep vol_wt act_wt obj_cost shipper         service       period price  \
# 0     7.62   0.53   1273    20581    DTDC         PREMIUM      4 Day/s   565
# 1     7.62   0.53   1273    20581    DTDC       STD EXP-A  4 - 5 Day/s   240
# 2     7.62   0.53   1273    20581    DTDC       AIR CARGO  4 - 5 Day/s   360
# 6     7.62   0.53   1273    20581    DTDC  GROUND EXPRESS  4 - 5 Day/s   240
# 8     10.1  0.361    118    14986    DTDC         PREMIUM      5 Day/s   380
# ...    ...    ...    ...      ...     ...             ...          ...   ...
# 4328  22.5  2.605   1322     5704    DTDC  GROUND EXPRESS  7 - 8 Day/s   850
# 4330  15.5  0.657    731    20324    DTDC         PREMIUM       4 days   625
# 4332  15.5  0.657    731    20324    DTDC       AIR CARGO   5 - 6 days   600
# 4334  15.5  0.657    731    20324    DTDC       STD EXP-A   5 - 6 days   325
# 4336  15.5  0.657    731    20324    DTDC  GROUND EXPRESS  9 - 10 days   625
#
#      add_price price_risk_sur price_carr_risk_sur price_own_risk_sur  \
# 0            0           1051                1051                614
# 1            0            726                 726                289
# 2            0            846                 846                409
# 6            0            726                 726                289
# 8            0            734                 734                415
# ...        ...            ...                 ...                ...
# 4328         0            985                 985                880
# 4330         0           1105                1105                673
# 4332         0           1080                1080                648
# 4334         0            805                 805                373
# 4336         0           1105                1105                673
#
#      price_with_ins gstPer basePrice  gst gst_risk_sur gst_carr_risk_sur  \
# 0              1462     18       565   86          160               160
# 1              1137     18       240   37          111               111
# 2              1257     18       360   55          129               129
# 6              1137     18       240   37          111               111
# 8              1033     18       380   58          112               112
# ...             ...    ...       ...  ...          ...               ...
# 4328           1099     18       850  130          150               150
# 4330           1511     18       625   95          169               169
# 4332           1486     18       600   92          165               165
# 4334           1211     18       325   50          123               123
# 4336           1511     18       625   95          169               169
#
#      gst_own_risk_sur         edd charge_wt
# 0                  94         NaN      1273
# 1                  44         NaN      1273
# 2                  62         NaN      1273
# 6                  44         NaN      1273
# 8                  63         NaN       362
# ...               ...         ...       ...
# 4328              134         NaN      2743
# 4330              103  2024-08-31       731
# 4332               99  2024-09-02       731
# 4334               57  2024-09-02       731
# 4336              103  2024-09-06       731
#
# [2169 rows x 29 columns]

# %%
# Stack all dfs together to generate consolidated df
cdf=pd.concat([df1,df2,df3,df4,df5,df6]).reset_index(drop=True)

# %%
# cdf=pd.concat([df1,df2,df3]).reset_index(drop=True)

# %%
# Drop irrelevant columns

cdf = cdf.drop(columns=['dtdc_del', 'box','shipper','add_price','price_risk_sur', 'price_carr_risk_sur',
       'price_own_risk_sur', 'price_with_ins','gst_risk_sur', 'gst_carr_risk_sur', 'gst_own_risk_sur', 'edd','dst_state']);

# %%
# cdf has around 45k records for a supplier
cdf
# Out:
#        org_pin  dst_pin    len    wid    dep  vol_wt  act_wt  obj_cost  price  \
# 0       600032   686503  22.86  15.24   7.62     530    1273     20581    240
# 1       362225   686503  22.00  11.50   7.50     380     428     18639    190
# 2       600032   620002  17.70  10.10  10.10     361     187     19663    100
# 3       110037   620002  34.00  33.00  35.00    7854    4697     12818   1125
# 4       110043   620002  27.70  20.90  22.50    2605    1882      8726   1605
# ...        ...      ...    ...    ...    ...     ...     ...       ...    ...
# 10119   573102   581421  48.10  40.40  38.90   15118   17136      4959   1170
# 10120   580008   591307  68.58  33.02  35.56   16105   14917     17273   1105
# 10121   591307   580008  68.58  33.02  35.56   16105   14917     17273   1105
# 10122   583229   585416  55.00  45.00  41.00   20295    8490     14357   2835
# 10123   585416   583229  55.00  45.00  41.00   20295    8490     14357   1430
#
#        charge_wt  eddDays  org_state    org_lat   org_long  org_hasMetroCity  \
# 0           1273        5  TAMILNADU  13.035944  80.208667                 1
# 1            428        7    GUJARAT  21.148343  70.140988                 0
# 2            362        3  TAMILNADU  13.035944  80.208667                 1
# 3           8268        6      DELHI  28.540000  77.115528                 1
# 4           2606        2      DELHI  28.604120  76.979822                 1
# ...          ...      ...        ...        ...        ...               ...
# 10119      17136        5  KARNATAKA  12.755000  76.105000                 1
# 10120      16953        4  KARNATAKA  15.461754  75.001708                 1
# 10121      16953        3  KARNATAKA  16.165925  74.822257                 1
# 10122      20295        3  KARNATAKA  15.607711  76.646063                 1
# 10123      21364        5  KARNATAKA  17.911639  77.519361                 1
#
#        org_isSpecialDest  org_po_del  dst_state    dst_lat   dst_long  \
# 0                      0       False     KERALA   9.605166  76.671168
# 1                      0        True     KERALA   9.605166  76.671168
# 2                      0       False  TAMILNADU  10.826333  78.695920
# 3                      0       False  TAMILNADU  10.826333  78.695920
# 4                      0       False  TAMILNADU  10.826333  78.695920
# ...                  ...         ...        ...        ...        ...
# 10119                  0        True  KARNATAKA  14.070965  74.505158
# 10120                  0       False  KARNATAKA  16.165925  74.822257
# 10121                  0       False  KARNATAKA  15.461754  75.001708
# 10122                  0        True  KARNATAKA  17.911639  77.519361
# 10123                  0        True  KARNATAKA  15.607711  76.646063
#
#        dst_hasMetroCity  dst_isSpecialDest  dst_po_del
# 0                     0                  0        True
# 1                     0                  0        True
# 2                     1                  0       False
# 3                     1                  0       False
# 4                     1                  0       False
# ...                 ...                ...         ...
# 10119                 1                  0        True
# 10120                 1                  0       False
# 10121                 1                  0       False
# 10122                 1                  0        True
# 10123                 1                  0        True
#
# [10124 rows x 23 columns]

# %%
# For the time being we will only use one service for the cheapest option having min cost, we will add create another model to predict EDD
# Futher model can be developed by categorising different services as additional parameter

min_pr_grp=cdf.groupby(['org_pin', 'dst_pin'])['price']

# %%
cdf=cdf.assign(min_price=min_pr_grp.transform(min))

# %%
cdf['min_price']
# Out:
# 0         240
# 1         240
# 2         240
# 3         240
# 4         190
#          ...
# 45347     100
# 45348    2835
# 45349    1430
# 45350    1430
# 45351    1430
# Name: min_price, Length: 45352, dtype: object

# %%
cdf['is_min_price'] = cdf.apply(lambda x: 1 if x['price'] == x['min_price'] else 0, axis=1)

# %%
cdf=cdf.drop(cdf[cdf.is_min_price == 0].index)

# %%
cdf.service.unique()
# Out:
# array(['STD EXP-A', 'GROUND EXPRESS', 'PREMIUM', 'AIR CARGO',
#        'PRIME TIME PLUS 1400', 'PRIME TIME PLUS 1600',
#        'PRIME TIME PLUS 1200'], dtype=object)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11726 entries, 1 to 45351
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   org_pin       11726 non-null  object
#  1   dst_pin       11726 non-null  object
#  2   po_del        11726 non-null  object
#  3   len           11726 non-null  object
#  4   wid           11726 non-null  object
#  5   dep           11726 non-null  object
#  6   vol_wt        11726 non-null  object
#  7   act_wt        11726 non-null  object
#  8   obj_cost      11726 non-null  object
#  9   service       11726 non-null  object
#  10  period        11726 non-null  object
#  11  price         11726 non-null  object
#  12  gstPer        11726 non-null  object
#  13  basePrice     11726 non-null  object
#  14  gst           11726 non-null  object
#  15  charge_wt     11726 non-null  object
#  16  min_price     11726 non-null  object
#  17  is_min_price  11726 non-null  int64
# dtypes: int64(1), object(17)
# memory usage: 1.7+ MB

# %%
cdf['org_pin'] = cdf['org_pin'].astype(int)
cdf['dst_pin'] = cdf['dst_pin'].astype(int)
cdf['po_del'] = cdf['po_del'].apply(lambda x: 1 if x == 'True' else 0)
cdf['vol_wt'] = cdf['vol_wt'].astype(float)
cdf['vol_wt'] = cdf['vol_wt'].apply(lambda x: x*1000)
cdf['price'] = cdf['price'].astype(int)
cdf['len']=cdf['len'].astype(float)
cdf['wid']=cdf['wid'].astype(float)
cdf['dep']=cdf['dep'].astype(float)
cdf['vol_wt'] = cdf['vol_wt'].round(0).astype(int)
cdf['act_wt'] = cdf['act_wt'].astype(int)
cdf['obj_cost'] = cdf['obj_cost'].astype(int)
cdf['price'] = cdf['price'].astype(int)
cdf['gstPer'] = cdf['gstPer'].astype(int)
cdf['basePrice'] = cdf['basePrice'].astype(int)
cdf['gst'] = cdf['gst'].astype(int)
cdf['charge_wt'] = cdf['charge_wt'].astype(int)
cdf['min_price'] = cdf['min_price'].astype(int)

# %%
cdf=cdf.drop_duplicates(["org_pin","dst_pin"])

# %%
cdf = cdf.reset_index(drop=True)

# %%
eddDays=cdf['period'].apply(lambda x: x[0])

# %%
cdf['period'].unique()
# Out:
# array(['4 - 5 Day/s', '5 - 6 Day/s', '4 Day/s', '3 - 4 Day/s', '3 Day/s',
#        '6 - 7 Day/s', '2 - 3 Day/s', '9 Day/s', '5 Day/s', '7 Day/s',
#        '8 Day/s', '4 - 5 days', '10 - 11 Day/s', '7 - 8 Day/s',
#        '14 - 15 Day/s', '1 - 2 Day/s', '6 Day/s', '1 Day/s', '2 Day/s',
#        '8 - 9 Day/s', '10 Day/s', '9 - 10 Day/s', '12 - 13 Day/s',
#        '11 - 12 Day/s', '14 Day/s', '5 - 6 days', '3 - 4 days',
#        'Next Business Day by 2 PM', '7 - 8 days', '1 day', '3 days',
#        '10 - 11 days', '6 - 7 days', '13 - 14 Day/s', '8 - 9 days',
#        '4 days', '11 Day/s', '1 - 2 days', '6 days', '5 days',
#        '9 - 10 days', '12 - 13 days', '12 Day/s', '7 days', '17 Day/s',
#        '13 Day/s', 'Next Business Day by 4 PM', '2 - 3 days', '18 Day/s',
#        '16 - 17 Day/s', '15 - 16 Day/s', '2 days', '11 - 12 days',
#        'Next Business Day by 12 PM'], dtype=object)

# %%
cdf['eddDays'] = 0

# %%
cdf['eddDays'][cdf.loc[(cdf['period'] == 'Next Business Day by 12 PM') | (cdf['period'] == 'Next Business Day by 4 PM') | (cdf['period'] == 'Next Business Day by 2 PM')].index] = 1
# Out:
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3098010839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == 'Next Business Day by 12 PM') | (cdf['period'] == 'Next Business Day by 4 PM') | (cdf['period'] == 'Next Business Day by 2 PM')].index] = 1

# %%
# Manually fetch edd value due to inconsistant pattern
cdf['eddDays'][cdf.loc[(cdf['period'] == '2 days')].index] = 2
cdf['eddDays'][cdf.loc[(cdf['period'] == '4 - 5 Day/s')].index] = 5
cdf['eddDays'][cdf.loc[(cdf['period'] == '5 - 6 Day/s')].index] = 6
cdf['eddDays'][cdf.loc[(cdf['period'] == '4 Day/s')].index] = 4
cdf['eddDays'][cdf.loc[(cdf['period'] == '3 - 4 Day/s')].index] = 4
cdf['eddDays'][cdf.loc[(cdf['period'] == '3 Day/s')].index] = 3
cdf['eddDays'][cdf.loc[(cdf['period'] == '2 - 3 Day/s')].index] = 3
cdf['eddDays'][cdf.loc[(cdf['period'] == '9 Day/s')].index] = 9
cdf['eddDays'][cdf.loc[(cdf['period'] == '5 Day/s')].index] = 5
cdf['eddDays'][cdf.loc[(cdf['period'] == '7 Day/s')].index] = 7
cdf['eddDays'][cdf.loc[(cdf['period'] == '8 Day/s')].index] = 8
cdf['eddDays'][cdf.loc[(cdf['period'] == '10 - 11 Day/s')].index] = 11
cdf['eddDays'][cdf.loc[(cdf['period'] == '7 - 8 Day/s')].index] = 8
cdf['eddDays'][cdf.loc[(cdf['period'] == '14 - 15 Day/s')].index] = 15
cdf['eddDays'][cdf.loc[(cdf['period'] == '1 - 2 Day/s')].index] = 2
cdf['eddDays'][cdf.loc[(cdf['period'] == '6 Day/s')].index] = 6
cdf['eddDays'][cdf.loc[(cdf['period'] == '1 Day/s')].index] = 1
cdf['eddDays'][cdf.loc[(cdf['period'] == '2 Day/s')].index] = 2
cdf['eddDays'][cdf.loc[(cdf['period'] == '8 - 9 Day/s')].index] = 9
cdf['eddDays'][cdf.loc[(cdf['period'] == '10 Day/s')].index] = 10
cdf['eddDays'][cdf.loc[(cdf['period'] == '9 - 10 Day/s')].index] = 10
cdf['eddDays'][cdf.loc[(cdf['period'] == '12 - 13 Day/s')].index] = 13
cdf['eddDays'][cdf.loc[(cdf['period'] == '11 - 12 Day/s')].index] = 12
cdf['eddDays'][cdf.loc[(cdf['period'] == '14 Day/s')].index] = 14
cdf['eddDays'][cdf.loc[(cdf['period'] == '5 - 6 days')].index] = 6
cdf['eddDays'][cdf.loc[(cdf['period'] == '3 - 4 days')].index] = 4
cdf['eddDays'][cdf.loc[(cdf['period'] == '7 - 8 days')].index] = 8
cdf['eddDays'][cdf.loc[(cdf['period'] == '1 day')].index] = 1
cdf['eddDays'][cdf.loc[(cdf['period'] == '3 days')].index] = 3
cdf['eddDays'][cdf.loc[(cdf['period'] == '10 - 11 days')].index] = 11
cdf['eddDays'][cdf.loc[(cdf['period'] == '13 - 14 Day/s')].index] = 14
cdf['eddDays'][cdf.loc[(cdf['period'] == '8 - 9 days')].index] = 9
cdf['eddDays'][cdf.loc[(cdf['period'] == '4 days')].index] = 4
cdf['eddDays'][cdf.loc[(cdf['period'] == '11 Day/s')].index] = 11
cdf['eddDays'][cdf.loc[(cdf['period'] == '1 - 2 days')].index] = 2
cdf['eddDays'][cdf.loc[(cdf['period'] == '6 days')].index] = 6
cdf['eddDays'][cdf.loc[(cdf['period'] == '5 days')].index] = 5
cdf['eddDays'][cdf.loc[(cdf['period'] == '9 - 10 days')].index] = 10
cdf['eddDays'][cdf.loc[(cdf['period'] == '12 - 13 days')].index] = 13
cdf['eddDays'][cdf.loc[(cdf['period'] == '12 Day/s')].index] = 12
cdf['eddDays'][cdf.loc[(cdf['period'] == '7 days')].index] = 7
cdf['eddDays'][cdf.loc[(cdf['period'] == '17 Day/s')].index] = 17
cdf['eddDays'][cdf.loc[(cdf['period'] == '13 Day/s')].index] = 13
cdf['eddDays'][cdf.loc[(cdf['period'] == '2 - 3 days')].index] = 3
cdf['eddDays'][cdf.loc[(cdf['period'] == '18 Day/s')].index] = 18
cdf['eddDays'][cdf.loc[(cdf['period'] == '16 - 17 Day/s')].index] = 17
cdf['eddDays'][cdf.loc[(cdf['period'] == '15 - 16 Day/s')].index] = 16
cdf['eddDays'][cdf.loc[(cdf['period'] == '11 - 12 days')].index] = 12
cdf['eddDays'][cdf.loc[(cdf['period'] == '6 - 7 Day/s')].index] = 7
cdf['eddDays'][cdf.loc[(cdf['period'] == '4 - 5 days')].index] = 5
cdf['eddDays'][cdf.loc[(cdf['period'] == '6 - 7 days')].index] = 7
# Out:
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '2 days')].index] = 2
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '4 - 5 Day/s')].index] = 5
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '5 - 6 Day/s')].index] = 6
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '4 Day/s')].index] = 4
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '3 - 4 Day/s')].index] = 4
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '3 Day/s')].index] = 3
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '2 - 3 Day/s')].index] = 3
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '9 Day/s')].index] = 9
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '5 Day/s')].index] = 5
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '7 Day/s')].index] = 7
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '8 Day/s')].index] = 8
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '10 - 11 Day/s')].index] = 11
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '7 - 8 Day/s')].index] = 8
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '14 - 15 Day/s')].index] = 15
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '1 - 2 Day/s')].index] = 2
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '6 Day/s')].index] = 6
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '1 Day/s')].index] = 1
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '2 Day/s')].index] = 2
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '8 - 9 Day/s')].index] = 9
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '10 Day/s')].index] = 10
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '9 - 10 Day/s')].index] = 10
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '12 - 13 Day/s')].index] = 13
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '11 - 12 Day/s')].index] = 12
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '14 Day/s')].index] = 14
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '5 - 6 days')].index] = 6
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '3 - 4 days')].index] = 4
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '7 - 8 days')].index] = 8
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '1 day')].index] = 1
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '3 days')].index] = 3
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '10 - 11 days')].index] = 11
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '13 - 14 Day/s')].index] = 14
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '8 - 9 days')].index] = 9
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '4 days')].index] = 4
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '11 Day/s')].index] = 11
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '1 - 2 days')].index] = 2
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '6 days')].index] = 6
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '5 days')].index] = 5
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '9 - 10 days')].index] = 10
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '12 - 13 days')].index] = 13
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '12 Day/s')].index] = 12
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '7 days')].index] = 7
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '17 Day/s')].index] = 17
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '13 Day/s')].index] = 13
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '2 - 3 days')].index] = 3
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '18 Day/s')].index] = 18
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '16 - 17 Day/s')].index] = 17
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '15 - 16 Day/s')].index] = 16
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '11 - 12 days')].index] = 12
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '6 - 7 Day/s')].index] = 7
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '4 - 5 days')].index] = 5
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3502655848.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdf['eddDays'][cdf.loc[(cdf['period'] == '6 - 7 days')].index] = 7

# %%
cdf['eddDays'].unique()
# Out:
# array([ 5,  6,  4,  3,  7,  9,  8, 11, 15,  2,  1, 10, 13, 12, 14, 17, 18,
#        16])

# %%
cdf=cdf.drop(columns=['is_min_price'])

# %%
pincode_data = pincode_data.drop(columns=['Dtdc_del'])

# %%
pincode_data1 = pincode_data.copy()
pincode_data2 = pincode_data.copy()

# %%
# We will join pincode data for both origin and dest to the consolidated df 
pincode_data1['org_pin']=pincode_data1['Pincode']
pincode_data1['org_state']=pincode_data1['State']
pincode_data1['org_lat']=pincode_data1['LatitudeNum']
pincode_data1['org_long']=pincode_data1['LongitudeNum']
pincode_data1['org_hasMetroCity']=pincode_data1['hasMetroCity']
pincode_data1['org_isSpecialDest']=pincode_data1['isSpecialDest']
pincode_data1['org_po_del']=pincode_data1['Po_del']

# %%
pincode_data2['dst_pin']=pincode_data2['Pincode']
pincode_data2['dst_state']=pincode_data2['State']
pincode_data2['dst_lat']=pincode_data2['LatitudeNum']
pincode_data2['dst_long']=pincode_data2['LongitudeNum']
pincode_data2['dst_hasMetroCity']=pincode_data2['hasMetroCity']
pincode_data2['dst_isSpecialDest']=pincode_data2['isSpecialDest']
pincode_data2['dst_po_del']=pincode_data2['Po_del']

# %%
pincode_data1=pincode_data1.drop(columns=['Pincode', 'State', 'LatitudeNum', 'LongitudeNum', 'hasMetroCity', 'isSpecialDest', 'Po_del'])
pincode_data2=pincode_data2.drop(columns=['Pincode', 'State', 'LatitudeNum', 'LongitudeNum', 'hasMetroCity', 'isSpecialDest', 'Po_del'])

# %%
cdf = pd.merge(cdf, pincode_data1, on='org_pin')

# %%
cdf = pd.merge(cdf, pincode_data2, on='dst_pin')

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10124 entries, 0 to 10123
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   org_pin            10124 non-null  int64
#  1   dst_pin            10124 non-null  int64
#  2   po_del             10124 non-null  int64
#  3   len                10124 non-null  float64
#  4   wid                10124 non-null  float64
#  5   dep                10124 non-null  float64
#  6   vol_wt             10124 non-null  int64
#  7   act_wt             10124 non-null  int64
#  8   obj_cost           10124 non-null  int64
#  9   service            10124 non-null  object
#  10  period             10124 non-null  object
#  11  price              10124 non-null  int64
#  12  gstPer             10124 non-null  int64
#  13  basePrice          10124 non-null  int64
#  14  gst                10124 non-null  int64
#  15  charge_wt          10124 non-null  int64
#  16  min_price          10124 non-null  int64
#  17  eddDays            10124 non-null  int64
#  18  org_state          10124 non-null  object
#  19  org_lat            10124 non-null  float64
#  20  org_long           10124 non-null  float64
#  21  org_hasMetroCity   10124 non-null  int64
#  22  org_isSpecialDest  10124 non-null  int64
#  23  org_po_del         10124 non-null  bool
#  24  dst_state          10124 non-null  object
#  25  dst_lat            10124 non-null  float64
#  26  dst_long           10124 non-null  float64
#  27  dst_hasMetroCity   10124 non-null  int64
#  28  dst_isSpecialDest  10124 non-null  int64
#  29  dst_po_del         10124 non-null  bool
# dtypes: bool(2), float64(7), int64(17), object(4)
# memory usage: 2.3+ MB

# %%
cdf.to_csv('minPriceModelDataTestUpdated31Aug.csv')

# %%
checkDf = pd.read_csv('minPriceModelDataTestUpdated31Aug.csv')

# %%
checkDf.loc[checkDf['org_pin'] == 110037]
# Out:
#       Unnamed: 0  org_pin  dst_pin  po_del   len   wid   dep  vol_wt  act_wt  \
# 3              3   110037   620002       0  34.0  33.0  35.0    7854    4697
# 751          751   110037   110056       1  48.1  40.4  38.9   15118   19901
# 2918        2918   110037   110007       0  17.7  10.1  10.1     361     669
#
#       obj_cost         service       period  price  gstPer  basePrice  gst  \
# 3        12818  GROUND EXPRESS  5 - 6 Day/s   1125      18       1125  172
# 751      15526       AIR CARGO  1 - 2 Day/s   1000      18       1000  153
# 2918     17149       STD EXP-A  1 - 2 Day/s    115      18        115   18
#
#       charge_wt  min_price  eddDays org_state  org_lat   org_long  \
# 3          8268       1125        6     DELHI    28.54  77.115528
# 751       19901       1000        2     DELHI    28.54  77.115528
# 2918        669        115        2     DELHI    28.54  77.115528
#
#       org_hasMetroCity  org_isSpecialDest  org_po_del  dst_state    dst_lat  \
# 3                    1                  0       False  TAMILNADU  10.826333
# 751                  1                  0       False      DELHI  28.682722
# 2918                 1                  0       False      DELHI  28.676611
#
#        dst_long  dst_hasMetroCity  dst_isSpecialDest  dst_po_del
# 3     78.695920                 1                  0       False
# 751   77.111111                 1                  0        True
# 2918  77.206111                 1                  0       False

# %%
cdf=cdf.drop(columns=['period','service','gst','gstPer','basePrice','po_del'])

# %%
cdf=cdf.drop(columns=['min_price'])

# %%
df = cdf.copy()

# %%
df
# Out:
#        org_pin  dst_pin    len    wid    dep  vol_wt  act_wt  obj_cost  price  \
# 0       600032   686503  22.86  15.24   7.62     530    1273     20581    240
# 1       362225   686503  22.00  11.50   7.50     380     428     18639    190
# 2       600032   620002  17.70  10.10  10.10     361     187     19663    100
# 3       110037   620002  34.00  33.00  35.00    7854    4697     12818   1125
# 4       110043   620002  27.70  20.90  22.50    2605    1882      8726   1605
# ...        ...      ...    ...    ...    ...     ...     ...       ...    ...
# 10119   573102   581421  48.10  40.40  38.90   15118   17136      4959   1170
# 10120   580008   591307  68.58  33.02  35.56   16105   14917     17273   1105
# 10121   591307   580008  68.58  33.02  35.56   16105   14917     17273   1105
# 10122   583229   585416  55.00  45.00  41.00   20295    8490     14357   2835
# 10123   585416   583229  55.00  45.00  41.00   20295    8490     14357   1430
#
#        charge_wt  eddDays  org_state    org_lat   org_long  org_hasMetroCity  \
# 0           1273        5  TAMILNADU  13.035944  80.208667                 1
# 1            428        7    GUJARAT  21.148343  70.140988                 0
# 2            362        3  TAMILNADU  13.035944  80.208667                 1
# 3           8268        6      DELHI  28.540000  77.115528                 1
# 4           2606        2      DELHI  28.604120  76.979822                 1
# ...          ...      ...        ...        ...        ...               ...
# 10119      17136        5  KARNATAKA  12.755000  76.105000                 1
# 10120      16953        4  KARNATAKA  15.461754  75.001708                 1
# 10121      16953        3  KARNATAKA  16.165925  74.822257                 1
# 10122      20295        3  KARNATAKA  15.607711  76.646063                 1
# 10123      21364        5  KARNATAKA  17.911639  77.519361                 1
#
#        org_isSpecialDest  org_po_del  dst_state    dst_lat   dst_long  \
# 0                      0       False     KERALA   9.605166  76.671168
# 1                      0        True     KERALA   9.605166  76.671168
# 2                      0       False  TAMILNADU  10.826333  78.695920
# 3                      0       False  TAMILNADU  10.826333  78.695920
# 4                      0       False  TAMILNADU  10.826333  78.695920
# ...                  ...         ...        ...        ...        ...
# 10119                  0        True  KARNATAKA  14.070965  74.505158
# 10120                  0       False  KARNATAKA  16.165925  74.822257
# 10121                  0       False  KARNATAKA  15.461754  75.001708
# 10122                  0        True  KARNATAKA  17.911639  77.519361
# 10123                  0        True  KARNATAKA  15.607711  76.646063
#
#        dst_hasMetroCity  dst_isSpecialDest  dst_po_del
# 0                     0                  0        True
# 1                     0                  0        True
# 2                     1                  0       False
# 3                     1                  0       False
# 4                     1                  0       False
# ...                 ...                ...         ...
# 10119                 1                  0        True
# 10120                 1                  0       False
# 10121                 1                  0       False
# 10122                 1                  0        True
# 10123                 1                  0        True
#
# [10124 rows x 23 columns]

# %%
import pickle
stateLableEncoder = []
with open('stateLE.pkl','rb') as f:
     stateLableEncoder = pickle.load(f)

# %%
stateLableEncoder
# Out:
# LabelEncoder()

# %%
st=pincode_data['State'].unique()

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['org_state', 'dst_state'], dtype='object')

# %%
cat_col=[]
le=stateLableEncoder
for i in df.select_dtypes(include="object").columns:
    cat_col.append(i)
    df[i]=le.transform(df[i])
    
cat_col
# Out:
# ['org_state', 'dst_state']

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#        org_pin  dst_pin    len    wid    dep  vol_wt  act_wt  obj_cost  price  \
# 0       600032   686503  22.86  15.24   7.62     530    1273     20581    240
# 1       362225   686503  22.00  11.50   7.50     380     428     18639    190
# 2       600032   620002  17.70  10.10  10.10     361     187     19663    100
# 3       110037   620002  34.00  33.00  35.00    7854    4697     12818   1125
# 4       110043   620002  27.70  20.90  22.50    2605    1882      8726   1605
# ...        ...      ...    ...    ...    ...     ...     ...       ...    ...
# 10119   573102   581421  48.10  40.40  38.90   15118   17136      4959   1170
# 10120   580008   591307  68.58  33.02  35.56   16105   14917     17273   1105
# 10121   591307   580008  68.58  33.02  35.56   16105   14917     17273   1105
# 10122   583229   585416  55.00  45.00  41.00   20295    8490     14357   2835
# 10123   585416   583229  55.00  45.00  41.00   20295    8490     14357   1430
#
#        charge_wt  eddDays  org_state    org_lat   org_long  org_hasMetroCity  \
# 0           1273        5         29  13.035944  80.208667                 1
# 1            428        7          9  21.148343  70.140988                 0
# 2            362        3         29  13.035944  80.208667                 1
# 3           8268        6          7  28.540000  77.115528                 1
# 4           2606        2          7  28.604120  76.979822                 1
# ...          ...      ...        ...        ...        ...               ...
# 10119      17136        5         14  12.755000  76.105000                 1
# 10120      16953        4         14  15.461754  75.001708                 1
# 10121      16953        3         14  16.165925  74.822257                 1
# 10122      20295        3         14  15.607711  76.646063                 1
# 10123      21364        5         14  17.911639  77.519361                 1
#
#        org_isSpecialDest  org_po_del  dst_state    dst_lat   dst_long  \
# 0                      0       False         15   9.605166  76.671168
# 1                      0        True         15   9.605166  76.671168
# 2                      0       False         29  10.826333  78.695920
# 3                      0       False         29  10.826333  78.695920
# 4                      0       False         29  10.826333  78.695920
# ...                  ...         ...        ...        ...        ...
# 10119                  0        True         14  14.070965  74.505158
# 10120                  0       False         14  16.165925  74.822257
# 10121                  0       False         14  15.461754  75.001708
# 10122                  0        True         14  17.911639  77.519361
# 10123                  0        True         14  15.607711  76.646063
#
#        dst_hasMetroCity  dst_isSpecialDest  dst_po_del
# 0                     0                  0        True
# 1                     0                  0        True
# 2                     1                  0       False
# 3                     1                  0       False
# 4                     1                  0       False
# ...                 ...                ...         ...
# 10119                 1                  0        True
# 10120                 1                  0       False
# 10121                 1                  0       False
# 10122                 1                  0        True
# 10123                 1                  0        True
#
# [10124 rows x 23 columns]

# %%
df["chr_wt"] = df[["act_wt", "vol_wt"]].max(axis=1)

# %%
df=df.drop(['charge_wt'],axis=1)

# %%
df
# Out:
#        org_pin  dst_pin    len    wid    dep  vol_wt  act_wt  obj_cost  price  \
# 0       600032   686503  22.86  15.24   7.62     530    1273     20581    240
# 1       362225   686503  22.00  11.50   7.50     380     428     18639    190
# 2       600032   620002  17.70  10.10  10.10     361     187     19663    100
# 3       110037   620002  34.00  33.00  35.00    7854    4697     12818   1125
# 4       110043   620002  27.70  20.90  22.50    2605    1882      8726   1605
# ...        ...      ...    ...    ...    ...     ...     ...       ...    ...
# 10119   573102   581421  48.10  40.40  38.90   15118   17136      4959   1170
# 10120   580008   591307  68.58  33.02  35.56   16105   14917     17273   1105
# 10121   591307   580008  68.58  33.02  35.56   16105   14917     17273   1105
# 10122   583229   585416  55.00  45.00  41.00   20295    8490     14357   2835
# 10123   585416   583229  55.00  45.00  41.00   20295    8490     14357   1430
#
#        eddDays  org_state    org_lat   org_long  org_hasMetroCity  \
# 0            5         29  13.035944  80.208667                 1
# 1            7          9  21.148343  70.140988                 0
# 2            3         29  13.035944  80.208667                 1
# 3            6          7  28.540000  77.115528                 1
# 4            2          7  28.604120  76.979822                 1
# ...        ...        ...        ...        ...               ...
# 10119        5         14  12.755000  76.105000                 1
# 10120        4         14  15.461754  75.001708                 1
# 10121        3         14  16.165925  74.822257                 1
# 10122        3         14  15.607711  76.646063                 1
# 10123        5         14  17.911639  77.519361                 1
#
#        org_isSpecialDest  org_po_del  dst_state    dst_lat   dst_long  \
# 0                      0       False         15   9.605166  76.671168
# 1                      0        True         15   9.605166  76.671168
# 2                      0       False         29  10.826333  78.695920
# 3                      0       False         29  10.826333  78.695920
# 4                      0       False         29  10.826333  78.695920
# ...                  ...         ...        ...        ...        ...
# 10119                  0        True         14  14.070965  74.505158
# 10120                  0       False         14  16.165925  74.822257
# 10121                  0       False         14  15.461754  75.001708
# 10122                  0        True         14  17.911639  77.519361
# 10123                  0        True         14  15.607711  76.646063
#
#        dst_hasMetroCity  dst_isSpecialDest  dst_po_del  chr_wt
# 0                     0                  0        True    1273
# 1                     0                  0        True     428
# 2                     1                  0       False     361
# 3                     1                  0       False    7854
# 4                     1                  0       False    2605
# ...                 ...                ...         ...     ...
# 10119                 1                  0        True   17136
# 10120                 1                  0       False   16105
# 10121                 1                  0       False   16105
# 10122                 1                  0        True   20295
# 10123                 1                  0        True   20295
#
# [10124 rows x 23 columns]

# %%
# Function to calculate haversine distance between two lat long coordinates, it is accurate to ~1m in terms of point on earth
def haversine_np(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)
    
    All args must be of equal length.    
    
    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    
    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
    
    c = 2 * np.arcsin(np.sqrt(a))
    km = 6378.137 * c
    return km

# %%
df['distance'] = haversine_np(df['org_long'],df['org_lat'],df['dst_long'],df['dst_lat'])

# %%
df
# Out:
#        org_pin  dst_pin    len    wid    dep  vol_wt  act_wt  obj_cost  price  \
# 0       600032   686503  22.86  15.24   7.62     530    1273     20581    240
# 1       362225   686503  22.00  11.50   7.50     380     428     18639    190
# 2       600032   620002  17.70  10.10  10.10     361     187     19663    100
# 3       110037   620002  34.00  33.00  35.00    7854    4697     12818   1125
# 4       110043   620002  27.70  20.90  22.50    2605    1882      8726   1605
# ...        ...      ...    ...    ...    ...     ...     ...       ...    ...
# 10119   573102   581421  48.10  40.40  38.90   15118   17136      4959   1170
# 10120   580008   591307  68.58  33.02  35.56   16105   14917     17273   1105
# 10121   591307   580008  68.58  33.02  35.56   16105   14917     17273   1105
# 10122   583229   585416  55.00  45.00  41.00   20295    8490     14357   2835
# 10123   585416   583229  55.00  45.00  41.00   20295    8490     14357   1430
#
#        eddDays  org_state    org_lat   org_long  org_hasMetroCity  \
# 0            5         29  13.035944  80.208667                 1
# 1            7          9  21.148343  70.140988                 0
# 2            3         29  13.035944  80.208667                 1
# 3            6          7  28.540000  77.115528                 1
# 4            2          7  28.604120  76.979822                 1
# ...        ...        ...        ...        ...               ...
# 10119        5         14  12.755000  76.105000                 1
# 10120        4         14  15.461754  75.001708                 1
# 10121        3         14  16.165925  74.822257                 1
# 10122        3         14  15.607711  76.646063                 1
# 10123        5         14  17.911639  77.519361                 1
#
#        org_isSpecialDest  org_po_del  dst_state    dst_lat   dst_long  \
# 0                      0       False         15   9.605166  76.671168
# 1                      0        True         15   9.605166  76.671168
# 2                      0       False         29  10.826333  78.695920
# 3                      0       False         29  10.826333  78.695920
# 4                      0       False         29  10.826333  78.695920
# ...                  ...         ...        ...        ...        ...
# 10119                  0        True         14  14.070965  74.505158
# 10120                  0       False         14  16.165925  74.822257
# 10121                  0       False         14  15.461754  75.001708
# 10122                  0        True         14  17.911639  77.519361
# 10123                  0        True         14  15.607711  76.646063
#
#        dst_hasMetroCity  dst_isSpecialDest  dst_po_del  chr_wt     distance
# 0                     0                  0        True    1273   543.049398
# 1                     0                  0        True     428  1463.002661
# 2                     1                  0       False     361   296.048421
# 3                     1                  0       False    7854  1978.745116
# 4                     1                  0       False    2605  1987.077606
# ...                 ...                ...         ...     ...          ...
# 10119                 1                  0        True   17136   226.867973
# 10120                 1                  0       False   16105    80.709917
# 10121                 1                  0       False   16105    80.709917
# 10122                 1                  0        True   20295   272.839458
# 10123                 1                  0        True   20295   272.839458
#
# [10124 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10124 entries, 0 to 10123
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   org_pin            10124 non-null  int64
#  1   dst_pin            10124 non-null  int64
#  2   len                10124 non-null  float64
#  3   wid                10124 non-null  float64
#  4   dep                10124 non-null  float64
#  5   vol_wt             10124 non-null  int64
#  6   act_wt             10124 non-null  int64
#  7   obj_cost           10124 non-null  int64
#  8   price              10124 non-null  int64
#  9   eddDays            10124 non-null  int64
#  10  org_state          10124 non-null  int64
#  11  org_lat            10124 non-null  float64
#  12  org_long           10124 non-null  float64
#  13  org_hasMetroCity   10124 non-null  int64
#  14  org_isSpecialDest  10124 non-null  int64
#  15  org_po_del         10124 non-null  bool
#  16  dst_state          10124 non-null  int64
#  17  dst_lat            10124 non-null  float64
#  18  dst_long           10124 non-null  float64
#  19  dst_hasMetroCity   10124 non-null  int64
#  20  dst_isSpecialDest  10124 non-null  int64
#  21  dst_po_del         10124 non-null  bool
#  22  chr_wt             10124 non-null  int64
#  23  distance           10124 non-null  float64
# dtypes: bool(2), float64(8), int64(14)
# memory usage: 1.8 MB

# %%
df['dst_po_del'] = df['dst_po_del'].apply(lambda x: 1 if x == True else 0)
df['org_po_del'] = df['org_po_del'].apply(lambda x: 1 if x == True else 0)

# %%
corr_matrix = df.drop(columns=['price','eddDays'],axis=1).corr()

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib inline
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %%
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/73047246.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#                    org_pin   dst_pin       len       wid       dep    vol_wt  \
# org_pin                NaN  0.137726  0.019385  0.017593  0.019909  0.020296
# dst_pin                NaN       NaN  0.017693  0.021269  0.019370  0.018582
# len                    NaN       NaN       NaN  0.832804  0.789609  0.903371
# wid                    NaN       NaN       NaN       NaN  0.727343  0.796248
# dep                    NaN       NaN       NaN       NaN       NaN  0.887945
# vol_wt                 NaN       NaN       NaN       NaN       NaN       NaN
# act_wt                 NaN       NaN       NaN       NaN       NaN       NaN
# obj_cost               NaN       NaN       NaN       NaN       NaN       NaN
# org_state              NaN       NaN       NaN       NaN       NaN       NaN
# org_lat                NaN       NaN       NaN       NaN       NaN       NaN
# org_long               NaN       NaN       NaN       NaN       NaN       NaN
# org_hasMetroCity       NaN       NaN       NaN       NaN       NaN       NaN
# org_isSpecialDest      NaN       NaN       NaN       NaN       NaN       NaN
# org_po_del             NaN       NaN       NaN       NaN       NaN       NaN
# dst_state              NaN       NaN       NaN       NaN       NaN       NaN
# dst_lat                NaN       NaN       NaN       NaN       NaN       NaN
# dst_long               NaN       NaN       NaN       NaN       NaN       NaN
# dst_hasMetroCity       NaN       NaN       NaN       NaN       NaN       NaN
# dst_isSpecialDest      NaN       NaN       NaN       NaN       NaN       NaN
# dst_po_del             NaN       NaN       NaN       NaN       NaN       NaN
# chr_wt                 NaN       NaN       NaN       NaN       NaN       NaN
# distance               NaN       NaN       NaN       NaN       NaN       NaN
#
#                      act_wt  obj_cost  org_state   org_lat  org_long  \
# org_pin            0.014528 -0.001932   0.078373 -0.061644  0.045716
# dst_pin            0.014740  0.006784   0.085353 -0.010119  0.003203
# len                0.813780 -0.011823  -0.000530  0.005064 -0.000375
# wid                0.705859 -0.003525   0.002434  0.010197  0.005487
# dep                0.789211 -0.001472   0.011171  0.019314  0.015325
# vol_wt             0.908676 -0.002646   0.002432  0.006106  0.002036
# act_wt                  NaN  0.006582   0.000004  0.000392 -0.003310
# obj_cost                NaN       NaN  -0.004322  0.000091 -0.001265
# org_state               NaN       NaN        NaN -0.019308 -0.004707
# org_lat                 NaN       NaN        NaN       NaN  0.963684
# org_long                NaN       NaN        NaN       NaN       NaN
# org_hasMetroCity        NaN       NaN        NaN       NaN       NaN
# org_isSpecialDest       NaN       NaN        NaN       NaN       NaN
# org_po_del              NaN       NaN        NaN       NaN       NaN
# dst_state               NaN       NaN        NaN       NaN       NaN
# dst_lat                 NaN       NaN        NaN       NaN       NaN
# dst_long                NaN       NaN        NaN       NaN       NaN
# dst_hasMetroCity        NaN       NaN        NaN       NaN       NaN
# dst_isSpecialDest       NaN       NaN        NaN       NaN       NaN
# dst_po_del              NaN       NaN        NaN       NaN       NaN
# chr_wt                  NaN       NaN        NaN       NaN       NaN
# distance                NaN       NaN        NaN       NaN       NaN
#
#                    org_hasMetroCity  org_isSpecialDest  org_po_del  dst_state  \
# org_pin                    0.096999           0.192277    0.198650   0.082959
# dst_pin                   -0.113021           0.035137    0.070524   0.020081
# len                       -0.000402          -0.001239    0.010914  -0.004467
# wid                       -0.000635          -0.005072    0.019190   0.002613
# dep                        0.007904          -0.002486    0.008259   0.001846
# vol_wt                     0.004713           0.002609    0.010297  -0.003180
# act_wt                     0.009276          -0.000785    0.005959  -0.008920
# obj_cost                  -0.004037           0.001967   -0.007732   0.005251
# org_state                  0.265293          -0.152281    0.031016   0.088228
# org_lat                   -0.074669           0.026422   -0.010034   0.003082
# org_long                  -0.018141           0.009562    0.013934   0.007768
# org_hasMetroCity                NaN          -0.221184   -0.088653  -0.076310
# org_isSpecialDest               NaN                NaN   -0.028673   0.028677
# org_po_del                      NaN                NaN         NaN   0.062551
# dst_state                       NaN                NaN         NaN        NaN
# dst_lat                         NaN                NaN         NaN        NaN
# dst_long                        NaN                NaN         NaN        NaN
# dst_hasMetroCity                NaN                NaN         NaN        NaN
# dst_isSpecialDest               NaN                NaN         NaN        NaN
# dst_po_del                      NaN                NaN         NaN        NaN
# chr_wt                          NaN                NaN         NaN        NaN
# distance                        NaN                NaN         NaN        NaN
#
#                     dst_lat  dst_long  dst_hasMetroCity  dst_isSpecialDest  \
# org_pin           -0.001023  0.002552         -0.088289           0.032514
# dst_pin           -0.024617  0.054676          0.077097           0.155384
# len               -0.004324 -0.009961         -0.004286          -0.006366
# wid               -0.000748 -0.004990         -0.005668          -0.006308
# dep                0.008751  0.006552          0.001282           0.003743
# vol_wt             0.000071 -0.003752         -0.002604           0.004610
# act_wt            -0.002690 -0.004514          0.003009           0.001152
# obj_cost          -0.007375 -0.010355         -0.002159           0.006121
# org_state          0.007040  0.004946         -0.069343           0.027462
# org_lat            0.001279  0.001857          0.005284          -0.006412
# org_long          -0.001271 -0.000782          0.001666          -0.002541
# org_hasMetroCity   0.007392  0.004105          0.130423          -0.003260
# org_isSpecialDest -0.007531 -0.005843          0.000283           0.010863
# org_po_del        -0.006029 -0.002451         -0.033364           0.000782
# dst_state         -0.017955 -0.014187          0.297043          -0.213768
# dst_lat                 NaN  0.864946         -0.064747           0.018846
# dst_long                NaN       NaN         -0.028200           0.002034
# dst_hasMetroCity        NaN       NaN               NaN          -0.202565
# dst_isSpecialDest       NaN       NaN               NaN                NaN
# dst_po_del              NaN       NaN               NaN                NaN
# chr_wt                  NaN       NaN               NaN                NaN
# distance                NaN       NaN               NaN                NaN
#
#                    dst_po_del    chr_wt  distance
# org_pin              0.075861  0.019727  0.047557
# dst_pin              0.183738  0.018502  0.080095
# len                  0.008729  0.885771  0.016988
# wid                  0.017173  0.788206  0.022087
# dep                  0.004956  0.880684  0.012731
# vol_wt               0.007209  0.991603  0.014656
# act_wt               0.006152  0.940587  0.013393
# obj_cost            -0.012081 -0.000716  0.022612
# org_state            0.067464  0.001101  0.043452
# org_lat             -0.003950  0.004633  0.176458
# org_long             0.002276  0.001017  0.056200
# org_hasMetroCity    -0.055482  0.007910 -0.169368
# org_isSpecialDest    0.000585  0.002975  0.101991
# org_po_del           0.058962  0.009973  0.065522
# dst_state            0.061459 -0.004911  0.051045
# dst_lat              0.002507 -0.000555  0.181377
# dst_long             0.021016 -0.004271  0.108681
# dst_hasMetroCity    -0.136971  0.000297 -0.144564
# dst_isSpecialDest    0.025225  0.005444  0.095616
# dst_po_del                NaN  0.007527  0.067404
# chr_wt                    NaN       NaN  0.012840
# distance                  NaN       NaN       NaN

# %%
# Dropping irrelevant cols for minPrice pred
df.drop(['vol_wt','act_wt','org_lat','org_long','dst_lat','dst_long','len','wid','dep'],inplace=True,axis=1)

# %%
df
# Out:
#        org_pin  dst_pin  obj_cost  price  eddDays  org_state  \
# 0       600032   686503     20581    240        5         29
# 1       362225   686503     18639    190        7          9
# 2       600032   620002     19663    100        3         29
# 3       110037   620002     12818   1125        6          7
# 4       110043   620002      8726   1605        2          7
# ...        ...      ...       ...    ...      ...        ...
# 10119   573102   581421      4959   1170        5         14
# 10120   580008   591307     17273   1105        4         14
# 10121   591307   580008     17273   1105        3         14
# 10122   583229   585416     14357   2835        3         14
# 10123   585416   583229     14357   1430        5         14
#
#        org_hasMetroCity  org_isSpecialDest  org_po_del  dst_state  \
# 0                     1                  0           0         15
# 1                     0                  0           1         15
# 2                     1                  0           0         29
# 3                     1                  0           0         29
# 4                     1                  0           0         29
# ...                 ...                ...         ...        ...
# 10119                 1                  0           1         14
# 10120                 1                  0           0         14
# 10121                 1                  0           0         14
# 10122                 1                  0           1         14
# 10123                 1                  0           1         14
#
#        dst_hasMetroCity  dst_isSpecialDest  dst_po_del  chr_wt     distance
# 0                     0                  0           1    1273   543.049398
# 1                     0                  0           1     428  1463.002661
# 2                     1                  0           0     361   296.048421
# 3                     1                  0           0    7854  1978.745116
# 4                     1                  0           0    2605  1987.077606
# ...                 ...                ...         ...     ...          ...
# 10119                 1                  0           1   17136   226.867973
# 10120                 1                  0           0   16105    80.709917
# 10121                 1                  0           0   16105    80.709917
# 10122                 1                  0           1   20295   272.839458
# 10123                 1                  0           1   20295   272.839458
#
# [10124 rows x 15 columns]

# %%
# df['charge_wt_lg'] = np.log(df['charge_wt'])

# %%
corr_matrix = df.drop(columns=['price','eddDays'],axis=1).corr()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_21075/3578782581.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#                    org_pin   dst_pin  obj_cost  org_state  org_hasMetroCity  \
# org_pin                NaN  0.137726 -0.001932   0.078373          0.096999
# dst_pin                NaN       NaN  0.006784   0.085353         -0.113021
# obj_cost               NaN       NaN       NaN  -0.004322         -0.004037
# org_state              NaN       NaN       NaN        NaN          0.265293
# org_hasMetroCity       NaN       NaN       NaN        NaN               NaN
# org_isSpecialDest      NaN       NaN       NaN        NaN               NaN
# org_po_del             NaN       NaN       NaN        NaN               NaN
# dst_state              NaN       NaN       NaN        NaN               NaN
# dst_hasMetroCity       NaN       NaN       NaN        NaN               NaN
# dst_isSpecialDest      NaN       NaN       NaN        NaN               NaN
# dst_po_del             NaN       NaN       NaN        NaN               NaN
# chr_wt                 NaN       NaN       NaN        NaN               NaN
# distance               NaN       NaN       NaN        NaN               NaN
#
#                    org_isSpecialDest  org_po_del  dst_state  dst_hasMetroCity  \
# org_pin                     0.192277    0.198650   0.082959         -0.088289
# dst_pin                     0.035137    0.070524   0.020081          0.077097
# obj_cost                    0.001967   -0.007732   0.005251         -0.002159
# org_state                  -0.152281    0.031016   0.088228         -0.069343
# org_hasMetroCity           -0.221184   -0.088653  -0.076310          0.130423
# org_isSpecialDest                NaN   -0.028673   0.028677          0.000283
# org_po_del                       NaN         NaN   0.062551         -0.033364
# dst_state                        NaN         NaN        NaN          0.297043
# dst_hasMetroCity                 NaN         NaN        NaN               NaN
# dst_isSpecialDest                NaN         NaN        NaN               NaN
# dst_po_del                       NaN         NaN        NaN               NaN
# chr_wt                           NaN         NaN        NaN               NaN
# distance                         NaN         NaN        NaN               NaN
#
#                    dst_isSpecialDest  dst_po_del    chr_wt  distance
# org_pin                     0.032514    0.075861  0.019727  0.047557
# dst_pin                     0.155384    0.183738  0.018502  0.080095
# obj_cost                    0.006121   -0.012081 -0.000716  0.022612
# org_state                   0.027462    0.067464  0.001101  0.043452
# org_hasMetroCity           -0.003260   -0.055482  0.007910 -0.169368
# org_isSpecialDest           0.010863    0.000585  0.002975  0.101991
# org_po_del                  0.000782    0.058962  0.009973  0.065522
# dst_state                  -0.213768    0.061459 -0.004911  0.051045
# dst_hasMetroCity           -0.202565   -0.136971  0.000297 -0.144564
# dst_isSpecialDest                NaN    0.025225  0.005444  0.095616
# dst_po_del                       NaN         NaN  0.007527  0.067404
# chr_wt                           NaN         NaN       NaN  0.012840
# distance                         NaN         NaN       NaN       NaN

# %%
# df=df.drop(['charge_wt'],axis=1)

# %%
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %%
train, validate = \
              np.split(df.sample(frac=1, random_state=42), 
                       [int(.85*len(df))])

# %%
# We have split data into 2 sets already to do validation. train, validate and test to ensure higher comparison checking and tuning
# Out:
#       org_pin  dst_pin  obj_cost  price  charge_wt  eddDays  org_state  \
# 8442   755044   521182     12140    870       1233        5         24
# 3389   533221   249141     22327   1360       2171       10          1
# 3911   110077   110038      6275    150        380        2          7
# 5383   625014   306303      7989    325        755        8         29
# 552    683110   431402     21550   1044       8268        9         15
# ...       ...      ...       ...    ...        ...      ...        ...
# 5734   305621   562105      2559    190        330        5         27
# 5191   629179   788803     15684   2040      11630       12         29
# 5390   306303   625014      7989    325        755        5         27
# 860    794104   802301     18802   1280      15747        9         21
# 7270   628102   638458      8545    150        853        6         29
#
#       org_hasMetroCity  org_isSpecialDest  org_po_del  dst_state  \
# 8442                 0                  0           1          1
# 3389                 0                  0           1         33
# 3911                 1                  0           0          7
# 5383                 1                  0           0         27
# 552                  0                  0           1         19
# ...                ...                ...         ...        ...
# 5734                 0                  0           1         14
# 5191                 1                  0           1          3
# 5390                 0                  0           1         29
# 860                  0                  1           1          4
# 7270                 1                  0           1         29
#
#       dst_hasMetroCity  dst_isSpecialDest  dst_po_del     distance
# 8442                 0                  0           1   763.691724
# 3389                 0                  0           1  1634.276316
# 3911                 1                  0           0     7.415221
# 5383                 0                  0           1  1859.810128
# 552                  1                  0           1  8131.346733
# ...                ...                ...         ...          ...
# 5734                 1                  0           0  1441.770605
# 5191                 0                  1           1  2456.644845
# 5390                 1                  0           0  1859.810128
# 860                  0                  0           0   557.666654
# 7270                 1                  0           1   302.191199
#
# [1519 rows x 15 columns]

# %%
# x = train.drop(columns=['price','eddDays'],axis=1)
# y = train['price']

# %%
x = df.drop(columns=['price','eddDays'],axis=1)
y = df['price']

# %%
validate
# Out:
#       org_pin  dst_pin  obj_cost  price  charge_wt  eddDays  org_state  \
# 8442   755044   521182     12140    870       1233        5         24
# 3389   533221   249141     22327   1360       2171       10          1
# 3911   110077   110038      6275    150        380        2          7
# 5383   625014   306303      7989    325        755        8         29
# 552    683110   431402     21550   1044       8268        9         15
# ...       ...      ...       ...    ...        ...      ...        ...
# 5734   305621   562105      2559    190        330        5         27
# 5191   629179   788803     15684   2040      11630       12         29
# 5390   306303   625014      7989    325        755        5         27
# 860    794104   802301     18802   1280      15747        9         21
# 7270   628102   638458      8545    150        853        6         29
#
#       org_hasMetroCity  org_isSpecialDest  org_po_del  dst_state  \
# 8442                 0                  0           1          1
# 3389                 0                  0           1         33
# 3911                 1                  0           0          7
# 5383                 1                  0           0         27
# 552                  0                  0           1         19
# ...                ...                ...         ...        ...
# 5734                 0                  0           1         14
# 5191                 1                  0           1          3
# 5390                 0                  0           1         29
# 860                  0                  1           1          4
# 7270                 1                  0           1         29
#
#       dst_hasMetroCity  dst_isSpecialDest  dst_po_del     distance
# 8442                 0                  0           1   763.691724
# 3389                 0                  0           1  1634.276316
# 3911                 1                  0           0     7.415221
# 5383                 0                  0           1  1859.810128
# 552                  1                  0           1  8131.346733
# ...                ...                ...         ...          ...
# 5734                 1                  0           0  1441.770605
# 5191                 0                  1           1  2456.644845
# 5390                 1                  0           0  1859.810128
# 860                  0                  0           0   557.666654
# 7270                 1                  0           1   302.191199
#
# [1519 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=12)

# %%
x_train
# Out:
#       org_pin  dst_pin  obj_cost  org_state  org_hasMetroCity  \
# 7430   442301   175126      2093         19                 1
# 3743   688529   852111      5604         15                 0
# 737    622411   690539     20946         29                 1
# 8693   415613   500020      7015         19                 1
# 7124   731244   391770     12189         35                 1
# ...       ...      ...       ...        ...               ...
# 3714   845303   632301      2959          4                 0
# 7409   110053   110042      7106          7                 1
# 3325   805124   500056     11167          4                 0
# 9606   608304   712102     16706         29                 1
# 5787   600099   190009     22644         29                 1
#
#       org_isSpecialDest  org_po_del  dst_state  dst_hasMetroCity  \
# 7430                  0           0         11                 0
# 3743                  0           1          4                 0
# 737                   0           1         15                 0
# 8693                  0           1         30                 1
# 7124                  0           1          9                 0
# ...                 ...         ...        ...               ...
# 3714                  0           1         29                 1
# 7409                  0           0          7                 1
# 3325                  0           1         30                 1
# 9606                  0           1         35                 1
# 5787                  0           0         12                 0
#
#       dst_isSpecialDest  dst_po_del  chr_wt     distance
# 7430                  0           1    6363  1273.757978
# 3743                  0           1   20295  2126.170141
# 737                   0           1     587   277.793598
# 8693                  0           0   15118   553.120558
# 7124                  0           1    5775  1788.898520
# ...                 ...         ...     ...          ...
# 3714                  0           0    3900  1689.422649
# 7409                  0           0     963    13.798513
# 3325                  0           0    2150  1067.510691
# 9606                  0           1    1261  1609.454903
# 5787                  1           0    2113  2332.977569
#
# [8099 rows x 13 columns]

# %%
x_train.columns
# Out:
# Index(['org_pin', 'dst_pin', 'obj_cost', 'org_state', 'org_hasMetroCity',
#        'org_isSpecialDest', 'org_po_del', 'dst_state', 'dst_hasMetroCity',
#        'dst_isSpecialDest', 'dst_po_del', 'chr_wt', 'distance'],
#       dtype='object')

# %%
def test_accuracy(models):
    for i in models:
        i.fit(x_train,np.log(y_train))
        pred=pd.Series(i.predict(x_test)).abs()
        print("{}:{}".format(i,mean_squared_log_error(y_test, np.exp(pred))))

# %%
from sklearn.metrics import mean_squared_log_error
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor

# %%
ran=RandomForestRegressor(n_jobs=-1)
grad=GradientBoostingRegressor()
xgb=XGBRegressor()
lgb=LGBMRegressor()
cat=CatBoostRegressor(verbose=200)
ada=AdaBoostRegressor()
lr=LinearRegression()
rd=Ridge()
ls=Lasso()
knn=KNeighborsRegressor()

# %%
models=[xgb, ran, lgb, grad, cat,ada,lr,rd,ls,knn]
test_accuracy(models)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...):0.0817736911594073
# RandomForestRegressor(n_jobs=-1):0.0893950430599389
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000334 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1351
# [LightGBM] [Info] Number of data points in the train set: 8099, number of used features: 13
# [LightGBM] [Info] Start training from score 6.404140
# LGBMRegressor():0.07834726529567837
# GradientBoostingRegressor():0.09562821775240453
# Learning rate set to 0.056979
# 0:	learn: 0.9923920	total: 1.59ms	remaining: 1.59s
# 200:	learn: 0.2810169	total: 227ms	remaining: 902ms
# 400:	learn: 0.2493578	total: 456ms	remaining: 681ms
# 600:	learn: 0.2333959	total: 695ms	remaining: 461ms
# 800:	learn: 0.2194196	total: 943ms	remaining: 234ms
# 999:	learn: 0.2072966	total: 1.17s	remaining: 0us
# <catboost.core.CatBoostRegressor object at 0x30806f070>:0.07243332683623367
# AdaBoostRegressor():0.1786023553226376
# LinearRegression():0.43705156174668175
# Ridge():0.437049171826931
# Lasso():0.4597513477556093
# KNeighborsRegressor():0.6466833957647242

# %%
ypred_lgb = pd.Series(lgb.predict(x_test)).abs()
mean_squared_log_error(y_test,np.exp(ypred_lgb))
# Out:
# 0.05128494635463903

# %%
plt.figure(figsize=(12,8))
cat.fit(x,np.log(y))
a=zip(x.columns,cat.feature_importances_)
feat_imp=pd.DataFrame(a)
feat_imp.columns=["feat","imp"]
feat_imp=feat_imp.sort_values(by="imp", ascending=False)
sns.barplot(data=feat_imp, x="imp", y="feat");
# Out:
# Learning rate set to 0.059024
# 0:	learn: 0.9911872	total: 3.35ms	remaining: 3.35s
# 200:	learn: 0.2822747	total: 275ms	remaining: 1.09s
# 400:	learn: 0.2532199	total: 530ms	remaining: 792ms
# 600:	learn: 0.2369639	total: 799ms	remaining: 530ms
# 800:	learn: 0.2244033	total: 1.06s	remaining: 265ms
# 999:	learn: 0.2139004	total: 1.33s	remaining: 0us

# %%
plt.figure(figsize=(12,8))
lgb.fit(x,np.log(y))
a=zip(x.columns,lgb.feature_importances_)
feat_imp=pd.DataFrame(a)
feat_imp.columns=["feat","imp"]
feat_imp=feat_imp.sort_values(by="imp", ascending=False)
sns.barplot(data=feat_imp, x="imp", y="feat");
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000384 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1351
# [LightGBM] [Info] Number of data points in the train set: 10124, number of used features: 13
# [LightGBM] [Info] Start training from score 6.402361

# %%
ypred_cat1 = pd.Series(cat.predict(x_test)).abs()
mean_squared_log_error(y_test,np.exp(ypred_cat1))
# Out:
# 0.04339566247003262

# %%
ypred_lgb1 = pd.Series(lgb.predict(x_test)).abs()
mean_squared_log_error(y_test,np.exp(ypred_lgb1))
# Out:
# 0.05128494635463903

# %%
ypred_cat2 = pd.Series(cat.predict(validate.drop(columns=['price','eddDays']))).abs()
mean_squared_log_error(validate['price'],np.exp(ypred_cat2))
# Out:
# 0.047236140443853096

# %%
ypred_cat1
# Out:
# 0       7.161273
# 1       4.942287
# 2       5.283677
# 3       7.228803
# 4       6.099478
#           ...
# 2020    7.101728
# 2021    7.312458
# 2022    5.233719
# 2023    4.955831
# 2024    8.031381
# Length: 2025, dtype: float64

# %%
mean_squared_log_error(validate['price'],np.exp(ypred_cat))
# Out:
# 0.047236140443853096

# %%
yt=y_test.reset_index(drop=True)

# %%
from matplotlib.pyplot import figure
figure(figsize=(35, 25), dpi=100)
plt.plot(yt)
plt.tight_layout()
plt.plot(np.exp(ypred_lgb1))

# %%
yt2=validate['price'].reset_index(drop=True)

# %%
from matplotlib.pyplot import figure
figure(figsize=(35, 25), dpi=100)
plt.plot(yt2)
plt.tight_layout()
plt.plot(np.exp(ypred_cat2))

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_true=yt, y_pred=np.exp(ypred_lgb1))

# %%
r2
# Out:
# 0.766408305915723

# %%
import pickle
with open('min_price_pred_cat.pkl','wb') as f:
    pickle.dump(grad,f)

# %%
import pickle
with open('min_price_pred_lgb.pkl','wb') as f:
    pickle.dump(lgb,f)
