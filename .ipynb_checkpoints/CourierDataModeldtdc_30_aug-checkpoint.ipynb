# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from matplotlib.pyplot import figure

# %%
# Data has been read from different batches of data
# Data files for random dst and origin pincode
df=pd.read_csv("DataGen/dtdcData/0_1000_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])
df1=pd.read_csv("DataGen/dtdcData/0_1000_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])
df2=pd.read_csv("DataGen/dtdcData/1001_3000_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])
df3=pd.read_csv("DataGen/dtdcData2/3001_13000_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])

# Data files for interstate pincodes
df4=pd.read_csv("DataGen/dtdcData3/0_200_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])
df5=pd.read_csv("DataGen/dtdcData3/201_400_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])
df6=pd.read_csv("DataGen/dtdcData3/401_600_master_dtdc.csv",dtype='unicode',names=["org_pin", "dst_pin", "dst_state", "po_del", "dtdc_del", "box","len","wid","dep","vol_wt","act_wt","obj_cost","shipper","service","period","price","add_price","price_risk_sur","price_carr_risk_sur","price_own_risk_sur","price_with_ins","gstPer","basePrice","gst","gst_risk_sur","gst_carr_risk_sur","gst_own_risk_sur","edd","charge_wt"])

# %%
# Get all Pincode data for domestic model
pincode_data=pd.read_csv("DataGen/india_pincode_geo_metro.csv")

# %%
pincode_data=pincode_data.drop(columns=['id'])

# %%
# Dropping duplicate rows
df1=df1.drop_duplicates()
df2=df2.drop_duplicates()
df3=df3.drop_duplicates()
df4=df4.drop_duplicates()
df5=df5.drop_duplicates()
df6=df6.drop_duplicates()

# %%
df1.columns
# Out:
# Index(['org_pin', 'dst_pin', 'dst_state', 'po_del', 'dtdc_del', 'box', 'len',
#        'wid', 'dep', 'vol_wt', 'act_wt', 'obj_cost', 'shipper', 'service',
#        'period', 'price', 'add_price', 'price_risk_sur', 'price_carr_risk_sur',
#        'price_own_risk_sur', 'price_with_ins', 'gstPer', 'basePrice', 'gst',
#        'gst_risk_sur', 'gst_carr_risk_sur', 'gst_own_risk_sur', 'edd',
#        'charge_wt'],
#       dtype='object')

# %%
# Drop irrelevant columns

df1 = df1.drop(columns=['dtdc_del', 'box','shipper','add_price','price_risk_sur', 'price_carr_risk_sur',
       'price_own_risk_sur', 'price_with_ins','gst_risk_sur', 'gst_carr_risk_sur', 'gst_own_risk_sur', 'edd']);

df2 = df2.drop(columns=['dtdc_del', 'box','shipper','add_price','price_risk_sur', 'price_carr_risk_sur',
       'price_own_risk_sur', 'price_with_ins','gst_risk_sur', 'gst_carr_risk_sur', 'gst_own_risk_sur', 'edd']);

df3 = df3.drop(columns=['dtdc_del', 'box','shipper','add_price','price_risk_sur', 'price_carr_risk_sur',
       'price_own_risk_sur', 'price_with_ins','gst_risk_sur', 'gst_carr_risk_sur', 'gst_own_risk_sur', 'edd']);

df4 = df4.drop(columns=['dtdc_del', 'box','shipper','add_price','price_risk_sur', 'price_carr_risk_sur',
       'price_own_risk_sur', 'price_with_ins','gst_risk_sur', 'gst_carr_risk_sur', 'gst_own_risk_sur', 'edd']);

df5 = df5.drop(columns=['dtdc_del', 'box','shipper','add_price','price_risk_sur', 'price_carr_risk_sur',
       'price_own_risk_sur', 'price_with_ins','gst_risk_sur', 'gst_carr_risk_sur', 'gst_own_risk_sur', 'edd']);

df6 = df6.drop(columns=['dtdc_del', 'box','shipper','add_price','price_risk_sur', 'price_carr_risk_sur',
       'price_own_risk_sur', 'price_with_ins','gst_risk_sur', 'gst_carr_risk_sur', 'gst_own_risk_sur', 'edd'])

# %%
# df6

# %%
# Stack all dfs together to generate consolidated df
cdf=pd.concat([df1,df2,df3,df4,df5,df6]).reset_index(drop=True)

# %%
# cdf=pd.concat([df1,df2,df3]).reset_index(drop=True)

# %%
# cdf has around 45k records for a supplier
cdf.sample(frac=1)
# Out:
#       org_pin dst_pin      dst_state po_del    len    wid   dep  vol_wt  \
# 11616  345021  628003      RAJASTHAN  False     55     45    41  20.295
# 34210  635804  680602      TAMILNADU   True     55     45    41  20.295
# 40847  110056  110077          DELHI  False   27.7   20.9  22.5   2.605
# 17025  276127  560026      KARNATAKA  False  22.86  15.24  7.62    0.53
# 31184  683542  466001  MADHYAPRADESH  False  22.86  15.24  7.62    0.53
# ...       ...     ...            ...    ...    ...    ...   ...     ...
# 32356  400083  680505    MAHARASHTRA  False  15.16  15.16     7   0.321
# 25985  391760  272126   UTTARPRADESH   True     34     33    35   7.854
# 44198  571302  576201      KARNATAKA  False     30     30    10     1.8
# 19312  176110  678583         KERALA   True     34     33     6   1.347
# 3799   302016  502301      TELANGANA   True     22   11.5   7.5  0.3795
#
#       act_wt obj_cost               service                     period price  \
# 11616   7454    23546             AIR CARGO                4 - 5 Day/s  4200
# 34210  20771     5382               PREMIUM                    5 Day/s  4305
# 40847    732     4631  PRIME TIME PLUS 1400  Next Business Day by 2 PM   545
# 17025   1225    17203        GROUND EXPRESS                6 - 7 Day/s   500
# 31184   1284     9653        GROUND EXPRESS              10 - 11 Day/s   580
# ...      ...      ...                   ...                        ...   ...
# 32356    663    15169             STD EXP-A                4 - 5 Day/s   325
# 25985   5898    12127               PREMIUM                    7 Day/s  4055
# 44198   1159     3446             AIR CARGO                4 - 5 Day/s   270
# 19312    165     5336             AIR CARGO                5 - 6 Day/s   600
# 3799     411     5058               PREMIUM                    3 Day/s   345
#
#       gstPer basePrice  gst charge_wt
# 11616     18      4200  641     20295
# 34210     18      4305  657     20771
# 40847     18       545   83      2606
# 17025     18       500   76      1225
# 31184     19       580   93      1284
# ...      ...       ...  ...       ...
# 32356     18       325   50       663
# 25985     18      4055  619      7854
# 44198     18       270   41      1800
# 19312     18       600   92      1347
# 3799      18       345   53       411
#
# [45352 rows x 17 columns]

# %%
cdf=cdf.drop(columns=['dst_state'])

# %%
# For the time being we will only use one service (Premium) for which is the fastest
# Another model can be added to predict EDD with same features

# %%
df1.service.unique()
# Out:
# array(['PREMIUM', 'STD EXP-A', 'AIR CARGO', 'GROUND EXPRESS',
#        'PRIME TIME PLUS 1400', 'PRIME TIME PLUS 1200',
#        'PRIME TIME PLUS 1600'], dtype=object)

# %%
cdf=cdf.drop(cdf[cdf.service.isin(['PRIME TIME PLUS 1600','STD EXP-A','AIR CARGO','GROUND EXPRESS','PRIME TIME PLUS 1200','PRIME TIME PLUS 1400'])].index)

# %%
cdf
# Out:
#       org_pin dst_pin po_del    len    wid   dep  vol_wt act_wt obj_cost  \
# 0      600032  686503   True  22.86  15.24  7.62    0.53   1273    20581
# 4      171001  394325   True   17.7   10.1  10.1   0.361    118    14986
# 8      131039  521104   True     34     33     6   1.347    942    10185
# 12     175131  614713  False     22   11.5   7.5  0.3795     59    19870
# 16     175131  614713  False     22   11.5   7.5  0.3795    991    10364
# ...       ...     ...    ...    ...    ...   ...     ...    ...      ...
# 45336  574241  576226   True     30     30    10     1.8   1238    10529
# 45340  590014  574243   True     22   11.5   7.5  0.3795    358     2457
# 45344  574243  590014   True     22   11.5   7.5  0.3795    358     2457
# 45348  583229  585416   True     55     45    41  20.295   8490    14357
# 45349  585416  583229   True     55     45    41  20.295   8490    14357
#
#        service   period price gstPer basePrice  gst charge_wt
# 0      PREMIUM  4 Day/s   565     18       565   86      1273
# 4      PREMIUM  5 Day/s   380     18       380   58       362
# 8      PREMIUM  3 Day/s   870     18       870  133      1347
# 12     PREMIUM  3 Day/s   380     18       380   58       380
# 16     PREMIUM  3 Day/s   625     18       625   95       991
# ...        ...      ...   ...    ...       ...  ...       ...
# 45336  PREMIUM  3 Day/s   475     18       475   72      1800
# 45340  PREMIUM  3 Day/s   220     18       220   34       380
# 45344  PREMIUM  1 Day/s   220     18       220   34       380
# 45348  PREMIUM  3 Day/s  2835     18      2835  432     20295
# 45349  PREMIUM  3 Day/s  2835     18      2835  432     20295
#
# [12450 rows x 16 columns]

# %%
cdf.drop_duplicates()
# Out:
#       org_pin dst_pin po_del    len    wid   dep  vol_wt act_wt obj_cost  \
# 0      600032  686503   True  22.86  15.24  7.62    0.53   1273    20581
# 4      171001  394325   True   17.7   10.1  10.1   0.361    118    14986
# 8      131039  521104   True     34     33     6   1.347    942    10185
# 12     175131  614713  False     22   11.5   7.5  0.3795     59    19870
# 16     175131  614713  False     22   11.5   7.5  0.3795    991    10364
# ...       ...     ...    ...    ...    ...   ...     ...    ...      ...
# 45336  574241  576226   True     30     30    10     1.8   1238    10529
# 45340  590014  574243   True     22   11.5   7.5  0.3795    358     2457
# 45344  574243  590014   True     22   11.5   7.5  0.3795    358     2457
# 45348  583229  585416   True     55     45    41  20.295   8490    14357
# 45349  585416  583229   True     55     45    41  20.295   8490    14357
#
#        service   period price gstPer basePrice  gst charge_wt
# 0      PREMIUM  4 Day/s   565     18       565   86      1273
# 4      PREMIUM  5 Day/s   380     18       380   58       362
# 8      PREMIUM  3 Day/s   870     18       870  133      1347
# 12     PREMIUM  3 Day/s   380     18       380   58       380
# 16     PREMIUM  3 Day/s   625     18       625   95       991
# ...        ...      ...   ...    ...       ...  ...       ...
# 45336  PREMIUM  3 Day/s   475     18       475   72      1800
# 45340  PREMIUM  3 Day/s   220     18       220   34       380
# 45344  PREMIUM  1 Day/s   220     18       220   34       380
# 45348  PREMIUM  3 Day/s  2835     18      2835  432     20295
# 45349  PREMIUM  3 Day/s  2835     18      2835  432     20295
#
# [12450 rows x 16 columns]

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12450 entries, 0 to 45349
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   org_pin    12450 non-null  object
#  1   dst_pin    12450 non-null  object
#  2   po_del     12450 non-null  object
#  3   len        12450 non-null  object
#  4   wid        12450 non-null  object
#  5   dep        12450 non-null  object
#  6   vol_wt     12450 non-null  object
#  7   act_wt     12450 non-null  object
#  8   obj_cost   12450 non-null  object
#  9   service    12450 non-null  object
#  10  period     12450 non-null  object
#  11  price      12450 non-null  object
#  12  gstPer     12450 non-null  object
#  13  basePrice  12450 non-null  object
#  14  gst        12450 non-null  object
#  15  charge_wt  12450 non-null  object
# dtypes: object(16)
# memory usage: 1.6+ MB

# %%
cdf['org_pin'] = cdf['org_pin'].astype(int)
cdf['dst_pin'] = cdf['dst_pin'].astype(int)
cdf['po_del'] = cdf['po_del'].apply(lambda x: 1 if x == 'True' else 0)
cdf['vol_wt'] = cdf['vol_wt'].astype(float)
cdf['vol_wt'] = cdf['vol_wt'].apply(lambda x: x*1000)
cdf['price'] = cdf['price'].astype(int)

# %%
cdf['len']=cdf['len'].astype(float)
cdf['wid']=cdf['wid'].astype(float)
cdf['dep']=cdf['dep'].astype(float)

# %%
cdf['vol_wt'] = cdf['vol_wt'].round(0).astype(int)

# %%
cdf['act_wt'] = cdf['act_wt'].astype(int)
cdf['obj_cost'] = cdf['obj_cost'].astype(int)
cdf['price'] = cdf['price'].astype(int)
cdf['gstPer'] = cdf['gstPer'].astype(int)
cdf['basePrice'] = cdf['basePrice'].astype(int)
cdf['gst'] = cdf['gst'].astype(int)
cdf['charge_wt'] = cdf['charge_wt'].astype(int)

# %%
cdf
# Out:
#        org_pin  dst_pin  po_del    len    wid    dep  vol_wt  act_wt  \
# 0       600032   686503       1  22.86  15.24   7.62     530    1273
# 4       171001   394325       1  17.70  10.10  10.10     361     118
# 8       131039   521104       1  34.00  33.00   6.00    1347     942
# 12      175131   614713       0  22.00  11.50   7.50     380      59
# 16      175131   614713       0  22.00  11.50   7.50     380     991
# ...        ...      ...     ...    ...    ...    ...     ...     ...
# 45336   574241   576226       1  30.00  30.00  10.00    1800    1238
# 45340   590014   574243       1  22.00  11.50   7.50     380     358
# 45344   574243   590014       1  22.00  11.50   7.50     380     358
# 45348   583229   585416       1  55.00  45.00  41.00   20295    8490
# 45349   585416   583229       1  55.00  45.00  41.00   20295    8490
#
#        obj_cost  service   period  price  gstPer  basePrice  gst  charge_wt
# 0         20581  PREMIUM  4 Day/s    565      18        565   86       1273
# 4         14986  PREMIUM  5 Day/s    380      18        380   58        362
# 8         10185  PREMIUM  3 Day/s    870      18        870  133       1347
# 12        19870  PREMIUM  3 Day/s    380      18        380   58        380
# 16        10364  PREMIUM  3 Day/s    625      18        625   95        991
# ...         ...      ...      ...    ...     ...        ...  ...        ...
# 45336     10529  PREMIUM  3 Day/s    475      18        475   72       1800
# 45340      2457  PREMIUM  3 Day/s    220      18        220   34        380
# 45344      2457  PREMIUM  1 Day/s    220      18        220   34        380
# 45348     14357  PREMIUM  3 Day/s   2835      18       2835  432      20295
# 45349     14357  PREMIUM  3 Day/s   2835      18       2835  432      20295
#
# [12450 rows x 16 columns]

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12450 entries, 0 to 45349
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   org_pin    12450 non-null  int64
#  1   dst_pin    12450 non-null  int64
#  2   po_del     12450 non-null  int64
#  3   len        12450 non-null  float64
#  4   wid        12450 non-null  float64
#  5   dep        12450 non-null  float64
#  6   vol_wt     12450 non-null  int64
#  7   act_wt     12450 non-null  int64
#  8   obj_cost   12450 non-null  int64
#  9   service    12450 non-null  object
#  10  period     12450 non-null  object
#  11  price      12450 non-null  int64
#  12  gstPer     12450 non-null  int64
#  13  basePrice  12450 non-null  int64
#  14  gst        12450 non-null  int64
#  15  charge_wt  12450 non-null  int64
# dtypes: float64(3), int64(11), object(2)
# memory usage: 1.6+ MB

# %%
pincode_data.columns
# Out:
# Index(['Pincode', 'Po_del', 'State', 'Dtdc_del', 'LatitudeNum', 'LongitudeNum',
#        'hasMetroCity', 'isSpecialDest'],
#       dtype='object')

# %%
pincode_data = pincode_data.drop(columns=['Dtdc_del'])

# %%
pincode_data1 = pincode_data.copy()
pincode_data2 = pincode_data.copy()

# %%
# We will join pincode data for both origin and dest to the consolidated df 
pincode_data1['org_pin']=pincode_data['Pincode']
pincode_data1['org_state']=pincode_data['State']
pincode_data1['org_lat']=pincode_data['LatitudeNum']
pincode_data1['org_long']=pincode_data['LongitudeNum']
pincode_data1['org_hasMetroCity']=pincode_data['hasMetroCity']
pincode_data1['org_isSpecialDest']=pincode_data['isSpecialDest']
pincode_data1['org_po_del']=pincode_data['Po_del']

# %%
pincode_data2['dst_pin']=pincode_data['Pincode']
pincode_data2['dst_state']=pincode_data['State']
pincode_data2['dst_lat']=pincode_data['LatitudeNum']
pincode_data2['dst_long']=pincode_data['LongitudeNum']
pincode_data2['dst_hasMetroCity']=pincode_data['hasMetroCity']
pincode_data2['dst_isSpecialDest']=pincode_data['isSpecialDest']
pincode_data2['dst_po_del']=pincode_data['Po_del']

# %%
pincode_data2
# Out:
#        Pincode  Po_del                     State  LatitudeNum  LongitudeNum  \
# 0       515631    True             ANDHRAPRADESH    14.561000     77.854260
# 1       515581    True             ANDHRAPRADESH    14.248000     78.254890
# 2       515571    True             ANDHRAPRADESH    13.922672     78.201171
# 3       515311    True             ANDHRAPRADESH    13.805106     77.043906
# 4       515281    True             ANDHRAPRADESH    14.128104     76.980103
# ...        ...     ...                       ...          ...           ...
# 19295   744209    True  ANDAMANANDNICOBARISLANDS    12.380685     92.802739
# 19296   744101   False  ANDAMANANDNICOBARISLANDS    11.665833     92.741111
# 19297   744203    True  ANDAMANANDNICOBARISLANDS    11.665833     92.741111
# 19298   744106    True  ANDAMANANDNICOBARISLANDS    11.665833     92.741111
# 19299   744112    True  ANDAMANANDNICOBARISLANDS    11.370000     92.430000
#
#        hasMetroCity  isSpecialDest  dst_pin                 dst_state  \
# 0                 0              0   515631             ANDHRAPRADESH
# 1                 0              0   515581             ANDHRAPRADESH
# 2                 0              0   515571             ANDHRAPRADESH
# 3                 0              0   515311             ANDHRAPRADESH
# 4                 0              0   515281             ANDHRAPRADESH
# ...             ...            ...      ...                       ...
# 19295             0              1   744209  ANDAMANANDNICOBARISLANDS
# 19296             0              1   744101  ANDAMANANDNICOBARISLANDS
# 19297             0              1   744203  ANDAMANANDNICOBARISLANDS
# 19298             0              1   744106  ANDAMANANDNICOBARISLANDS
# 19299             0              1   744112  ANDAMANANDNICOBARISLANDS
#
#          dst_lat   dst_long  dst_hasMetroCity  dst_isSpecialDest  dst_po_del
# 0      14.561000  77.854260                 0                  0        True
# 1      14.248000  78.254890                 0                  0        True
# 2      13.922672  78.201171                 0                  0        True
# 3      13.805106  77.043906                 0                  0        True
# 4      14.128104  76.980103                 0                  0        True
# ...          ...        ...               ...                ...         ...
# 19295  12.380685  92.802739                 0                  1        True
# 19296  11.665833  92.741111                 0                  1       False
# 19297  11.665833  92.741111                 0                  1        True
# 19298  11.665833  92.741111                 0                  1        True
# 19299  11.370000  92.430000                 0                  1        True
#
# [19300 rows x 14 columns]

# %%
pincode_data1=pincode_data1.drop(columns=['Pincode', 'State', 'LatitudeNum', 'LongitudeNum', 'hasMetroCity', 'isSpecialDest', 'Po_del'])
pincode_data2=pincode_data2.drop(columns=['Pincode', 'State', 'LatitudeNum', 'LongitudeNum', 'hasMetroCity', 'isSpecialDest', 'Po_del'])

# %%
pincode_data1
# Out:
#        org_pin                 org_state    org_lat   org_long  \
# 0       515631             ANDHRAPRADESH  14.561000  77.854260
# 1       515581             ANDHRAPRADESH  14.248000  78.254890
# 2       515571             ANDHRAPRADESH  13.922672  78.201171
# 3       515311             ANDHRAPRADESH  13.805106  77.043906
# 4       515281             ANDHRAPRADESH  14.128104  76.980103
# ...        ...                       ...        ...        ...
# 19295   744209  ANDAMANANDNICOBARISLANDS  12.380685  92.802739
# 19296   744101  ANDAMANANDNICOBARISLANDS  11.665833  92.741111
# 19297   744203  ANDAMANANDNICOBARISLANDS  11.665833  92.741111
# 19298   744106  ANDAMANANDNICOBARISLANDS  11.665833  92.741111
# 19299   744112  ANDAMANANDNICOBARISLANDS  11.370000  92.430000
#
#        org_hasMetroCity  org_isSpecialDest  org_po_del
# 0                     0                  0        True
# 1                     0                  0        True
# 2                     0                  0        True
# 3                     0                  0        True
# 4                     0                  0        True
# ...                 ...                ...         ...
# 19295                 0                  1        True
# 19296                 0                  1       False
# 19297                 0                  1        True
# 19298                 0                  1        True
# 19299                 0                  1        True
#
# [19300 rows x 7 columns]

# %%
cdf = pd.merge(cdf, pincode_data1, on='org_pin')

# %%
cdf = pd.merge(cdf, pincode_data2, on='dst_pin')

# %%
cdf
# Out:
#        org_pin  dst_pin  po_del    len    wid    dep  vol_wt  act_wt  \
# 0       600032   686503       1  22.86  15.24   7.62     530    1273
# 1       362225   686503       1  22.00  11.50   7.50     380     428
# 2       600032   620002       0  17.70  10.10  10.10     361     187
# 3       110037   620002       0  34.00  33.00  35.00    7854    4697
# 4       110037   620002       0  34.00  33.00  35.00    7854    4370
# ...        ...      ...     ...    ...    ...    ...     ...     ...
# 12435   581421   573102       1  48.10  40.40  38.90   15118   17136
# 12436   580008   591307       0  68.58  33.02  35.56   16105   14917
# 12437   591307   580008       0  68.58  33.02  35.56   16105   14917
# 12438   583229   585416       1  55.00  45.00  41.00   20295    8490
# 12439   585416   583229       1  55.00  45.00  41.00   20295    8490
#
#        obj_cost  service   period  price  gstPer  basePrice  gst  charge_wt  \
# 0         20581  PREMIUM  4 Day/s    565      18        565   86       1273
# 1         18639  PREMIUM  5 Day/s    380      18        380   58        428
# 2         19663  PREMIUM  1 Day/s    220      18        220   34        362
# 3         12818  PREMIUM  2 Day/s   4055      18       4055  619       7854
# 4          5715  PREMIUM  2 Day/s   4055      18       4055  619       7854
# ...         ...      ...      ...    ...     ...        ...  ...        ...
# 12435      4959  PREMIUM  3 Day/s   2430      18       2430  371      17136
# 12436     17273  PREMIUM  3 Day/s   2295      18       2295  350      16106
# 12437     17273  PREMIUM  1 Day/s   2295      18       2295  350      16106
# 12438     14357  PREMIUM  3 Day/s   2835      18       2835  432      20295
# 12439     14357  PREMIUM  3 Day/s   2835      18       2835  432      20295
#
#        org_state    org_lat   org_long  org_hasMetroCity  org_isSpecialDest  \
# 0      TAMILNADU  13.035944  80.208667                 1                  0
# 1        GUJARAT  21.148343  70.140988                 0                  0
# 2      TAMILNADU  13.035944  80.208667                 1                  0
# 3          DELHI  28.540000  77.115528                 1                  0
# 4          DELHI  28.540000  77.115528                 1                  0
# ...          ...        ...        ...               ...                ...
# 12435  KARNATAKA  14.070965  74.505158                 1                  0
# 12436  KARNATAKA  15.461754  75.001708                 1                  0
# 12437  KARNATAKA  16.165925  74.822257                 1                  0
# 12438  KARNATAKA  15.607711  76.646063                 1                  0
# 12439  KARNATAKA  17.911639  77.519361                 1                  0
#
#        org_po_del  dst_state    dst_lat   dst_long  dst_hasMetroCity  \
# 0           False     KERALA   9.605166  76.671168                 0
# 1            True     KERALA   9.605166  76.671168                 0
# 2           False  TAMILNADU  10.826333  78.695920                 1
# 3           False  TAMILNADU  10.826333  78.695920                 1
# 4           False  TAMILNADU  10.826333  78.695920                 1
# ...           ...        ...        ...        ...               ...
# 12435        True  KARNATAKA  12.755000  76.105000                 1
# 12436       False  KARNATAKA  16.165925  74.822257                 1
# 12437       False  KARNATAKA  15.461754  75.001708                 1
# 12438        True  KARNATAKA  17.911639  77.519361                 1
# 12439        True  KARNATAKA  15.607711  76.646063                 1
#
#        dst_isSpecialDest  dst_po_del
# 0                      0        True
# 1                      0        True
# 2                      0       False
# 3                      0       False
# 4                      0       False
# ...                  ...         ...
# 12435                  0        True
# 12436                  0       False
# 12437                  0       False
# 12438                  0        True
# 12439                  0        True
#
# [12440 rows x 28 columns]

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12440 entries, 0 to 12439
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   org_pin            12440 non-null  int64
#  1   dst_pin            12440 non-null  int64
#  2   po_del             12440 non-null  int64
#  3   len                12440 non-null  float64
#  4   wid                12440 non-null  float64
#  5   dep                12440 non-null  float64
#  6   vol_wt             12440 non-null  int64
#  7   act_wt             12440 non-null  int64
#  8   obj_cost           12440 non-null  int64
#  9   service            12440 non-null  object
#  10  period             12440 non-null  object
#  11  price              12440 non-null  int64
#  12  gstPer             12440 non-null  int64
#  13  basePrice          12440 non-null  int64
#  14  gst                12440 non-null  int64
#  15  charge_wt          12440 non-null  int64
#  16  org_state          12440 non-null  object
#  17  org_lat            12440 non-null  float64
#  18  org_long           12440 non-null  float64
#  19  org_hasMetroCity   12440 non-null  int64
#  20  org_isSpecialDest  12440 non-null  int64
#  21  org_po_del         12440 non-null  bool
#  22  dst_state          12440 non-null  object
#  23  dst_lat            12440 non-null  float64
#  24  dst_long           12440 non-null  float64
#  25  dst_hasMetroCity   12440 non-null  int64
#  26  dst_isSpecialDest  12440 non-null  int64
#  27  dst_po_del         12440 non-null  bool
# dtypes: bool(2), float64(7), int64(15), object(4)
# memory usage: 2.6+ MB

# %%
cdf.to_csv('modelDataTestUpdated30Aug.csv')

# %%
cdf = pd.read_csv('modelDataTestUpdated30Aug.csv')

# %%
cdf = cdf.drop(columns=['Unnamed: 0'])

# %%
cdf
# Out:
#        org_pin  dst_pin  po_del    len    wid    dep  vol_wt  act_wt  \
# 0       600032   686503       1  22.86  15.24   7.62     530    1273
# 1       362225   686503       1  22.00  11.50   7.50     380     428
# 2       600032   620002       0  17.70  10.10  10.10     361     187
# 3       110037   620002       0  34.00  33.00  35.00    7854    4697
# 4       110037   620002       0  34.00  33.00  35.00    7854    4370
# ...        ...      ...     ...    ...    ...    ...     ...     ...
# 12435   581421   573102       1  48.10  40.40  38.90   15118   17136
# 12436   580008   591307       0  68.58  33.02  35.56   16105   14917
# 12437   591307   580008       0  68.58  33.02  35.56   16105   14917
# 12438   583229   585416       1  55.00  45.00  41.00   20295    8490
# 12439   585416   583229       1  55.00  45.00  41.00   20295    8490
#
#        obj_cost  service   period  price  gstPer  basePrice  gst  charge_wt  \
# 0         20581  PREMIUM  4 Day/s    565      18        565   86       1273
# 1         18639  PREMIUM  5 Day/s    380      18        380   58        428
# 2         19663  PREMIUM  1 Day/s    220      18        220   34        362
# 3         12818  PREMIUM  2 Day/s   4055      18       4055  619       7854
# 4          5715  PREMIUM  2 Day/s   4055      18       4055  619       7854
# ...         ...      ...      ...    ...     ...        ...  ...        ...
# 12435      4959  PREMIUM  3 Day/s   2430      18       2430  371      17136
# 12436     17273  PREMIUM  3 Day/s   2295      18       2295  350      16106
# 12437     17273  PREMIUM  1 Day/s   2295      18       2295  350      16106
# 12438     14357  PREMIUM  3 Day/s   2835      18       2835  432      20295
# 12439     14357  PREMIUM  3 Day/s   2835      18       2835  432      20295
#
#        org_state    org_lat   org_long  org_hasMetroCity  org_isSpecialDest  \
# 0      TAMILNADU  13.035944  80.208667                 1                  0
# 1        GUJARAT  21.148343  70.140988                 0                  0
# 2      TAMILNADU  13.035944  80.208667                 1                  0
# 3          DELHI  28.540000  77.115528                 1                  0
# 4          DELHI  28.540000  77.115528                 1                  0
# ...          ...        ...        ...               ...                ...
# 12435  KARNATAKA  14.070965  74.505158                 1                  0
# 12436  KARNATAKA  15.461754  75.001708                 1                  0
# 12437  KARNATAKA  16.165925  74.822257                 1                  0
# 12438  KARNATAKA  15.607711  76.646063                 1                  0
# 12439  KARNATAKA  17.911639  77.519361                 1                  0
#
#        org_po_del  dst_state    dst_lat   dst_long  dst_hasMetroCity  \
# 0           False     KERALA   9.605166  76.671168                 0
# 1            True     KERALA   9.605166  76.671168                 0
# 2           False  TAMILNADU  10.826333  78.695920                 1
# 3           False  TAMILNADU  10.826333  78.695920                 1
# 4           False  TAMILNADU  10.826333  78.695920                 1
# ...           ...        ...        ...        ...               ...
# 12435        True  KARNATAKA  12.755000  76.105000                 1
# 12436       False  KARNATAKA  16.165925  74.822257                 1
# 12437       False  KARNATAKA  15.461754  75.001708                 1
# 12438        True  KARNATAKA  17.911639  77.519361                 1
# 12439        True  KARNATAKA  15.607711  76.646063                 1
#
#        dst_isSpecialDest  dst_po_del
# 0                      0        True
# 1                      0        True
# 2                      0       False
# 3                      0       False
# 4                      0       False
# ...                  ...         ...
# 12435                  0        True
# 12436                  0       False
# 12437                  0       False
# 12438                  0        True
# 12439                  0        True
#
# [12440 rows x 28 columns]

# %%
cdf=cdf.drop(columns=['period','service'])

# %%
cdf=cdf.drop(columns=['gst','gstPer','basePrice'])

# %%
cdf=cdf.drop(columns=['po_del'])

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12440 entries, 0 to 12439
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   org_pin            12440 non-null  int64
#  1   dst_pin            12440 non-null  int64
#  2   len                12440 non-null  float64
#  3   wid                12440 non-null  float64
#  4   dep                12440 non-null  float64
#  5   vol_wt             12440 non-null  int64
#  6   act_wt             12440 non-null  int64
#  7   obj_cost           12440 non-null  int64
#  8   price              12440 non-null  int64
#  9   charge_wt          12440 non-null  int64
#  10  org_state          12440 non-null  object
#  11  org_lat            12440 non-null  float64
#  12  org_long           12440 non-null  float64
#  13  org_hasMetroCity   12440 non-null  int64
#  14  org_isSpecialDest  12440 non-null  int64
#  15  org_po_del         12440 non-null  bool
#  16  dst_state          12440 non-null  object
#  17  dst_lat            12440 non-null  float64
#  18  dst_long           12440 non-null  float64
#  19  dst_hasMetroCity   12440 non-null  int64
#  20  dst_isSpecialDest  12440 non-null  int64
#  21  dst_po_del         12440 non-null  bool
# dtypes: bool(2), float64(7), int64(11), object(2)
# memory usage: 1.9+ MB

# %%
import pickle

with open('stateLE.pkl','rb') as f:
     stateLableEncoder = pickle.load(f)

# %%
stateLableEncoder=LabelEncoder()

# %%
st=pincode_data['State'].unique()

# %%
stateLableEncoder.fit(st)
# Out:
# LabelEncoder()

# %%
cdf.select_dtypes(include="object").columns
# Out:
# Index(['org_state', 'dst_state'], dtype='object')

# %%
cat_col=[]
le=stateLableEncoder
for i in cdf.select_dtypes(include="object").columns:
    cat_col.append(i)
    cdf[i]=le.transform(cdf[i])
    
cat_col
# Out:
# ['org_state', 'dst_state']

# %%
pd.set_option('display.max_columns', None)

# %%
cdf
# Out:
#        org_pin  dst_pin    len    wid    dep  vol_wt  act_wt  obj_cost  price  \
# 0       600032   686503  22.86  15.24   7.62     530    1273     20581    565
# 1       362225   686503  22.00  11.50   7.50     380     428     18639    380
# 2       600032   620002  17.70  10.10  10.10     361     187     19663    220
# 3       110037   620002  34.00  33.00  35.00    7854    4697     12818   4055
# 4       110037   620002  34.00  33.00  35.00    7854    4370      5715   4055
# ...        ...      ...    ...    ...    ...     ...     ...       ...    ...
# 12435   581421   573102  48.10  40.40  38.90   15118   17136      4959   2430
# 12436   580008   591307  68.58  33.02  35.56   16105   14917     17273   2295
# 12437   591307   580008  68.58  33.02  35.56   16105   14917     17273   2295
# 12438   583229   585416  55.00  45.00  41.00   20295    8490     14357   2835
# 12439   585416   583229  55.00  45.00  41.00   20295    8490     14357   2835
#
#        charge_wt  org_state    org_lat   org_long  org_hasMetroCity  \
# 0           1273         29  13.035944  80.208667                 1
# 1            428          9  21.148343  70.140988                 0
# 2            362         29  13.035944  80.208667                 1
# 3           7854          7  28.540000  77.115528                 1
# 4           7854          7  28.540000  77.115528                 1
# ...          ...        ...        ...        ...               ...
# 12435      17136         14  14.070965  74.505158                 1
# 12436      16106         14  15.461754  75.001708                 1
# 12437      16106         14  16.165925  74.822257                 1
# 12438      20295         14  15.607711  76.646063                 1
# 12439      20295         14  17.911639  77.519361                 1
#
#        org_isSpecialDest  org_po_del  dst_state    dst_lat   dst_long  \
# 0                      0       False         15   9.605166  76.671168
# 1                      0        True         15   9.605166  76.671168
# 2                      0       False         29  10.826333  78.695920
# 3                      0       False         29  10.826333  78.695920
# 4                      0       False         29  10.826333  78.695920
# ...                  ...         ...        ...        ...        ...
# 12435                  0        True         14  12.755000  76.105000
# 12436                  0       False         14  16.165925  74.822257
# 12437                  0       False         14  15.461754  75.001708
# 12438                  0        True         14  17.911639  77.519361
# 12439                  0        True         14  15.607711  76.646063
#
#        dst_hasMetroCity  dst_isSpecialDest  dst_po_del
# 0                     0                  0        True
# 1                     0                  0        True
# 2                     1                  0       False
# 3                     1                  0       False
# 4                     1                  0       False
# ...                 ...                ...         ...
# 12435                 1                  0        True
# 12436                 1                  0       False
# 12437                 1                  0       False
# 12438                 1                  0        True
# 12439                 1                  0        True
#
# [12440 rows x 22 columns]

# %%
cdf["charge_wt"] = cdf[["act_wt", "vol_wt"]].max(axis=1)

# %%
# Function to calculate haversine distance between two lat long coordinates, it is accurate to ~1m in terms of point on earth
def haversine_np(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)
    
    All args must be of equal length.    
    
    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    
    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
    
    c = 2 * np.arcsin(np.sqrt(a))
    km = 6378.137 * c
    return km

# %%
cdf['distance'] = haversine_np(cdf['org_long'],cdf['org_lat'],cdf['dst_long'],cdf['dst_lat'])

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12440 entries, 0 to 12439
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   org_pin            12440 non-null  int64
#  1   dst_pin            12440 non-null  int64
#  2   len                12440 non-null  float64
#  3   wid                12440 non-null  float64
#  4   dep                12440 non-null  float64
#  5   vol_wt             12440 non-null  int64
#  6   act_wt             12440 non-null  int64
#  7   obj_cost           12440 non-null  int64
#  8   price              12440 non-null  int64
#  9   charge_wt          12440 non-null  int64
#  10  org_state          12440 non-null  int64
#  11  org_lat            12440 non-null  float64
#  12  org_long           12440 non-null  float64
#  13  org_hasMetroCity   12440 non-null  int64
#  14  org_isSpecialDest  12440 non-null  int64
#  15  org_po_del         12440 non-null  bool
#  16  dst_state          12440 non-null  int64
#  17  dst_lat            12440 non-null  float64
#  18  dst_long           12440 non-null  float64
#  19  dst_hasMetroCity   12440 non-null  int64
#  20  dst_isSpecialDest  12440 non-null  int64
#  21  dst_po_del         12440 non-null  bool
#  22  distance           12440 non-null  float64
# dtypes: bool(2), float64(8), int64(13)
# memory usage: 2.0 MB

# %%
cdf['dst_po_del'] = cdf['dst_po_del'].apply(lambda x: 1 if x == True else 0)
cdf['org_po_del'] = cdf['org_po_del'].apply(lambda x: 1 if x == True else 0)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12440 entries, 0 to 12439
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   org_pin            12440 non-null  int64
#  1   dst_pin            12440 non-null  int64
#  2   len                12440 non-null  float64
#  3   wid                12440 non-null  float64
#  4   dep                12440 non-null  float64
#  5   vol_wt             12440 non-null  int64
#  6   act_wt             12440 non-null  int64
#  7   obj_cost           12440 non-null  int64
#  8   price              12440 non-null  int64
#  9   charge_wt          12440 non-null  int64
#  10  org_state          12440 non-null  int64
#  11  org_lat            12440 non-null  float64
#  12  org_long           12440 non-null  float64
#  13  org_hasMetroCity   12440 non-null  int64
#  14  org_isSpecialDest  12440 non-null  int64
#  15  org_po_del         12440 non-null  int64
#  16  dst_state          12440 non-null  int64
#  17  dst_lat            12440 non-null  float64
#  18  dst_long           12440 non-null  float64
#  19  dst_hasMetroCity   12440 non-null  int64
#  20  dst_isSpecialDest  12440 non-null  int64
#  21  dst_po_del         12440 non-null  int64
#  22  distance           12440 non-null  float64
# dtypes: float64(8), int64(15)
# memory usage: 2.2 MB

# %%
cdf_copy=cdf.copy()

# %%
cdf.loc[cdf['org_pin'] == 229404]
# Out:
#        org_pin  dst_pin    len    wid   dep  vol_wt  act_wt  obj_cost  price  \
# 12062   229404   141011  10.16  10.16  3.81      70     456      2293    305
#
#        charge_wt  org_state    org_lat   org_long  org_hasMetroCity  \
# 12062        456         34  26.234946  81.025194                 0
#
#        org_isSpecialDest  org_po_del  dst_state  dst_lat  dst_long  \
# 12062                  0           1         26  30.8691   75.9202
#
#        dst_hasMetroCity  dst_isSpecialDest  dst_po_del    distance
# 12062                 0                  0           1  717.636727

# %%
corr_matrix = cdf_copy.drop(['price'],axis=1).corr()

# %%
corr_matrix
# Out:
#                     org_pin   dst_pin       len       wid       dep    vol_wt  \
# org_pin            1.000000  0.146755  0.024494  0.026373  0.028240  0.028845
# dst_pin            0.146755  1.000000  0.023517  0.029654  0.028443  0.028304
# len                0.024494  0.023517  1.000000  0.831674  0.786836  0.902932
# wid                0.026373  0.029654  0.831674  1.000000  0.723049  0.793289
# dep                0.028240  0.028443  0.786836  0.723049  1.000000  0.887544
# vol_wt             0.028845  0.028304  0.902932  0.793289  0.887544  1.000000
# act_wt             0.026807  0.028372  0.811095  0.702921  0.788905  0.908377
# obj_cost          -0.001546  0.002606 -0.010314 -0.014077 -0.006611 -0.006586
# charge_wt          0.029656  0.029664  0.883570  0.784446  0.879310  0.990785
# org_state          0.085860  0.086890  0.003020  0.004250  0.011866  0.006058
# org_lat           -0.059183 -0.013728  0.003759  0.007095  0.016859  0.003383
# org_long           0.045127  0.001153 -0.001226  0.003254  0.013416  0.000318
# org_hasMetroCity   0.084766 -0.123848 -0.006319 -0.002487  0.003187 -0.000696
# org_isSpecialDest  0.203305  0.038754  0.002487 -0.000304  0.003606  0.007114
# org_po_del         0.209357  0.082986  0.014233  0.022875  0.015344  0.016158
# dst_state          0.085332  0.028545 -0.002851  0.002880  0.000499 -0.001902
# dst_lat            0.000571 -0.009211 -0.006557 -0.000435  0.010660 -0.000490
# dst_long           0.005244  0.057456 -0.010782 -0.003463  0.008924 -0.003026
# dst_hasMetroCity  -0.102656  0.065403 -0.014806 -0.011029 -0.007664 -0.012427
# dst_isSpecialDest  0.034118  0.167099 -0.004073 -0.002530  0.008611  0.007533
# dst_po_del         0.085582  0.193728  0.012634  0.020727  0.011790  0.012607
# distance           0.057254  0.089183  0.019673  0.026249  0.017341  0.017397
#
#                      act_wt  obj_cost  charge_wt  org_state   org_lat  \
# org_pin            0.026807 -0.001546   0.029656   0.085860 -0.059183
# dst_pin            0.028372  0.002606   0.029664   0.086890 -0.013728
# len                0.811095 -0.010314   0.883570   0.003020  0.003759
# wid                0.702921 -0.014077   0.784446   0.004250  0.007095
# dep                0.788905 -0.006611   0.879310   0.011866  0.016859
# vol_wt             0.908377 -0.006586   0.990785   0.006058  0.003383
# act_wt             1.000000  0.002594   0.942655   0.003630  0.004316
# obj_cost           0.002594  1.000000  -0.005409   0.004392 -0.012029
# charge_wt          0.942655 -0.005409   1.000000   0.004963  0.002333
# org_state          0.003630  0.004392   0.004963   1.000000 -0.020021
# org_lat            0.004316 -0.012029   0.002333  -0.020021  1.000000
# org_long           0.001302 -0.012571  -0.000411  -0.004971  0.964400
# org_hasMetroCity   0.000218 -0.005281   0.001146   0.256342 -0.072500
# org_isSpecialDest  0.004947  0.001372   0.007425  -0.156138  0.024944
# org_po_del         0.014618 -0.002034   0.017060   0.035351 -0.010233
# dst_state         -0.005380  0.013567  -0.002637   0.093604  0.009886
# dst_lat           -0.000894 -0.014766  -0.001300   0.004441  0.002051
# dst_long          -0.002523 -0.016497  -0.003822   0.003793  0.001758
# dst_hasMetroCity  -0.010312 -0.003631  -0.010713  -0.078145  0.018864
# dst_isSpecialDest  0.004426  0.000836   0.007809   0.033810 -0.006493
# dst_po_del         0.012763 -0.007863   0.013547   0.077321 -0.010832
# distance           0.022700  0.014680   0.017803   0.048474  0.162435
#
#                    org_long  org_hasMetroCity  org_isSpecialDest  org_po_del  \
# org_pin            0.045127          0.084766           0.203305    0.209357
# dst_pin            0.001153         -0.123848           0.038754    0.082986
# len               -0.001226         -0.006319           0.002487    0.014233
# wid                0.003254         -0.002487          -0.000304    0.022875
# dep                0.013416          0.003187           0.003606    0.015344
# vol_wt             0.000318         -0.000696           0.007114    0.016158
# act_wt             0.001302          0.000218           0.004947    0.014618
# obj_cost          -0.012571         -0.005281           0.001372   -0.002034
# charge_wt         -0.000411          0.001146           0.007425    0.017060
# org_state         -0.004971          0.256342          -0.156138    0.035351
# org_lat            0.964400         -0.072500           0.024944   -0.010233
# org_long           1.000000         -0.018335           0.009761    0.014381
# org_hasMetroCity  -0.018335          1.000000          -0.222802   -0.090869
# org_isSpecialDest  0.009761         -0.222802           1.000000   -0.022591
# org_po_del         0.014381         -0.090869          -0.022591    1.000000
# dst_state          0.014056         -0.086630           0.032563    0.069264
# dst_lat           -0.000819          0.005861          -0.008247   -0.002006
# dst_long          -0.001135          0.003432          -0.006565    0.001144
# dst_hasMetroCity   0.014053          0.127904           0.002692   -0.036685
# dst_isSpecialDest -0.002458          0.000899           0.016774   -0.005291
# dst_po_del        -0.004355         -0.059913          -0.002416    0.066844
# distance           0.043114         -0.172494           0.097874    0.073360
#
#                    dst_state   dst_lat  dst_long  dst_hasMetroCity  \
# org_pin             0.085332  0.000571  0.005244         -0.102656
# dst_pin             0.028545 -0.009211  0.057456          0.065403
# len                -0.002851 -0.006557 -0.010782         -0.014806
# wid                 0.002880 -0.000435 -0.003463         -0.011029
# dep                 0.000499  0.010660  0.008924         -0.007664
# vol_wt             -0.001902 -0.000490 -0.003026         -0.012427
# act_wt             -0.005380 -0.000894 -0.002523         -0.010312
# obj_cost            0.013567 -0.014766 -0.016497         -0.003631
# charge_wt          -0.002637 -0.001300 -0.003822         -0.010713
# org_state           0.093604  0.004441  0.003793         -0.078145
# org_lat             0.009886  0.002051  0.001758          0.018864
# org_long            0.014056 -0.000819 -0.001135          0.014053
# org_hasMetroCity   -0.086630  0.005861  0.003432          0.127904
# org_isSpecialDest   0.032563 -0.008247 -0.006565          0.002692
# org_po_del          0.069264 -0.002006  0.001144         -0.036685
# dst_state           1.000000 -0.020909 -0.016098          0.289169
# dst_lat            -0.020909  1.000000  0.910720         -0.062247
# dst_long           -0.016098  0.910720  1.000000         -0.030912
# dst_hasMetroCity    0.289169 -0.062247 -0.030912          1.000000
# dst_isSpecialDest  -0.215564  0.013309  0.001039         -0.204295
# dst_po_del          0.065824  0.006962  0.022960         -0.138761
# distance            0.058799  0.188890  0.120382         -0.145097
#
#                    dst_isSpecialDest  dst_po_del  distance
# org_pin                     0.034118    0.085582  0.057254
# dst_pin                     0.167099    0.193728  0.089183
# len                        -0.004073    0.012634  0.019673
# wid                        -0.002530    0.020727  0.026249
# dep                         0.008611    0.011790  0.017341
# vol_wt                      0.007533    0.012607  0.017397
# act_wt                      0.004426    0.012763  0.022700
# obj_cost                    0.000836   -0.007863  0.014680
# charge_wt                   0.007809    0.013547  0.017803
# org_state                   0.033810    0.077321  0.048474
# org_lat                    -0.006493   -0.010832  0.162435
# org_long                   -0.002458   -0.004355  0.043114
# org_hasMetroCity            0.000899   -0.059913 -0.172494
# org_isSpecialDest           0.016774   -0.002416  0.097874
# org_po_del                 -0.005291    0.066844  0.073360
# dst_state                  -0.215564    0.065824  0.058799
# dst_lat                     0.013309    0.006962  0.188890
# dst_long                    0.001039    0.022960  0.120382
# dst_hasMetroCity           -0.204295   -0.138761 -0.145097
# dst_isSpecialDest           1.000000    0.024248  0.087031
# dst_po_del                  0.024248    1.000000  0.072735
# distance                    0.087031    0.072735  1.000000

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %%
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_46070/73047246.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#                    org_pin   dst_pin       len       wid       dep    vol_wt  \
# org_pin                NaN  0.146755  0.024494  0.026373  0.028240  0.028845
# dst_pin                NaN       NaN  0.023517  0.029654  0.028443  0.028304
# len                    NaN       NaN       NaN  0.831674  0.786836  0.902932
# wid                    NaN       NaN       NaN       NaN  0.723049  0.793289
# dep                    NaN       NaN       NaN       NaN       NaN  0.887544
# vol_wt                 NaN       NaN       NaN       NaN       NaN       NaN
# act_wt                 NaN       NaN       NaN       NaN       NaN       NaN
# obj_cost               NaN       NaN       NaN       NaN       NaN       NaN
# charge_wt              NaN       NaN       NaN       NaN       NaN       NaN
# org_state              NaN       NaN       NaN       NaN       NaN       NaN
# org_lat                NaN       NaN       NaN       NaN       NaN       NaN
# org_long               NaN       NaN       NaN       NaN       NaN       NaN
# org_hasMetroCity       NaN       NaN       NaN       NaN       NaN       NaN
# org_isSpecialDest      NaN       NaN       NaN       NaN       NaN       NaN
# org_po_del             NaN       NaN       NaN       NaN       NaN       NaN
# dst_state              NaN       NaN       NaN       NaN       NaN       NaN
# dst_lat                NaN       NaN       NaN       NaN       NaN       NaN
# dst_long               NaN       NaN       NaN       NaN       NaN       NaN
# dst_hasMetroCity       NaN       NaN       NaN       NaN       NaN       NaN
# dst_isSpecialDest      NaN       NaN       NaN       NaN       NaN       NaN
# dst_po_del             NaN       NaN       NaN       NaN       NaN       NaN
# distance               NaN       NaN       NaN       NaN       NaN       NaN
#
#                      act_wt  obj_cost  charge_wt  org_state   org_lat  \
# org_pin            0.026807 -0.001546   0.029656   0.085860 -0.059183
# dst_pin            0.028372  0.002606   0.029664   0.086890 -0.013728
# len                0.811095 -0.010314   0.883570   0.003020  0.003759
# wid                0.702921 -0.014077   0.784446   0.004250  0.007095
# dep                0.788905 -0.006611   0.879310   0.011866  0.016859
# vol_wt             0.908377 -0.006586   0.990785   0.006058  0.003383
# act_wt                  NaN  0.002594   0.942655   0.003630  0.004316
# obj_cost                NaN       NaN  -0.005409   0.004392 -0.012029
# charge_wt               NaN       NaN        NaN   0.004963  0.002333
# org_state               NaN       NaN        NaN        NaN -0.020021
# org_lat                 NaN       NaN        NaN        NaN       NaN
# org_long                NaN       NaN        NaN        NaN       NaN
# org_hasMetroCity        NaN       NaN        NaN        NaN       NaN
# org_isSpecialDest       NaN       NaN        NaN        NaN       NaN
# org_po_del              NaN       NaN        NaN        NaN       NaN
# dst_state               NaN       NaN        NaN        NaN       NaN
# dst_lat                 NaN       NaN        NaN        NaN       NaN
# dst_long                NaN       NaN        NaN        NaN       NaN
# dst_hasMetroCity        NaN       NaN        NaN        NaN       NaN
# dst_isSpecialDest       NaN       NaN        NaN        NaN       NaN
# dst_po_del              NaN       NaN        NaN        NaN       NaN
# distance                NaN       NaN        NaN        NaN       NaN
#
#                    org_long  org_hasMetroCity  org_isSpecialDest  org_po_del  \
# org_pin            0.045127          0.084766           0.203305    0.209357
# dst_pin            0.001153         -0.123848           0.038754    0.082986
# len               -0.001226         -0.006319           0.002487    0.014233
# wid                0.003254         -0.002487          -0.000304    0.022875
# dep                0.013416          0.003187           0.003606    0.015344
# vol_wt             0.000318         -0.000696           0.007114    0.016158
# act_wt             0.001302          0.000218           0.004947    0.014618
# obj_cost          -0.012571         -0.005281           0.001372   -0.002034
# charge_wt         -0.000411          0.001146           0.007425    0.017060
# org_state         -0.004971          0.256342          -0.156138    0.035351
# org_lat            0.964400         -0.072500           0.024944   -0.010233
# org_long                NaN         -0.018335           0.009761    0.014381
# org_hasMetroCity        NaN               NaN          -0.222802   -0.090869
# org_isSpecialDest       NaN               NaN                NaN   -0.022591
# org_po_del              NaN               NaN                NaN         NaN
# dst_state               NaN               NaN                NaN         NaN
# dst_lat                 NaN               NaN                NaN         NaN
# dst_long                NaN               NaN                NaN         NaN
# dst_hasMetroCity        NaN               NaN                NaN         NaN
# dst_isSpecialDest       NaN               NaN                NaN         NaN
# dst_po_del              NaN               NaN                NaN         NaN
# distance                NaN               NaN                NaN         NaN
#
#                    dst_state   dst_lat  dst_long  dst_hasMetroCity  \
# org_pin             0.085332  0.000571  0.005244         -0.102656
# dst_pin             0.028545 -0.009211  0.057456          0.065403
# len                -0.002851 -0.006557 -0.010782         -0.014806
# wid                 0.002880 -0.000435 -0.003463         -0.011029
# dep                 0.000499  0.010660  0.008924         -0.007664
# vol_wt             -0.001902 -0.000490 -0.003026         -0.012427
# act_wt             -0.005380 -0.000894 -0.002523         -0.010312
# obj_cost            0.013567 -0.014766 -0.016497         -0.003631
# charge_wt          -0.002637 -0.001300 -0.003822         -0.010713
# org_state           0.093604  0.004441  0.003793         -0.078145
# org_lat             0.009886  0.002051  0.001758          0.018864
# org_long            0.014056 -0.000819 -0.001135          0.014053
# org_hasMetroCity   -0.086630  0.005861  0.003432          0.127904
# org_isSpecialDest   0.032563 -0.008247 -0.006565          0.002692
# org_po_del          0.069264 -0.002006  0.001144         -0.036685
# dst_state                NaN -0.020909 -0.016098          0.289169
# dst_lat                  NaN       NaN  0.910720         -0.062247
# dst_long                 NaN       NaN       NaN         -0.030912
# dst_hasMetroCity         NaN       NaN       NaN               NaN
# dst_isSpecialDest        NaN       NaN       NaN               NaN
# dst_po_del               NaN       NaN       NaN               NaN
# distance                 NaN       NaN       NaN               NaN
#
#                    dst_isSpecialDest  dst_po_del  distance
# org_pin                     0.034118    0.085582  0.057254
# dst_pin                     0.167099    0.193728  0.089183
# len                        -0.004073    0.012634  0.019673
# wid                        -0.002530    0.020727  0.026249
# dep                         0.008611    0.011790  0.017341
# vol_wt                      0.007533    0.012607  0.017397
# act_wt                      0.004426    0.012763  0.022700
# obj_cost                    0.000836   -0.007863  0.014680
# charge_wt                   0.007809    0.013547  0.017803
# org_state                   0.033810    0.077321  0.048474
# org_lat                    -0.006493   -0.010832  0.162435
# org_long                   -0.002458   -0.004355  0.043114
# org_hasMetroCity            0.000899   -0.059913 -0.172494
# org_isSpecialDest           0.016774   -0.002416  0.097874
# org_po_del                 -0.005291    0.066844  0.073360
# dst_state                  -0.215564    0.065824  0.058799
# dst_lat                     0.013309    0.006962  0.188890
# dst_long                    0.001039    0.022960  0.120382
# dst_hasMetroCity           -0.204295   -0.138761 -0.145097
# dst_isSpecialDest                NaN    0.024248  0.087031
# dst_po_del                       NaN         NaN  0.072735
# distance                         NaN         NaN       NaN

# %%
to_drop = [column for column in upper.columns if any(upper[column] > 0.9)]

# %%
to_drop
# Out:
# ['vol_wt', 'act_wt', 'charge_wt', 'org_long', 'dst_long']

# %%
cdf_copy.drop(['vol_wt','act_wt','org_lat','org_long','dst_lat','dst_long'],inplace=True,axis=1)

# %%
cdf_copy
# Out:
#        org_pin  dst_pin    len    wid    dep  obj_cost  price  charge_wt  \
# 0       600032   686503  22.86  15.24   7.62     20581    565       1273
# 1       362225   686503  22.00  11.50   7.50     18639    380        428
# 2       600032   620002  17.70  10.10  10.10     19663    220        361
# 3       110037   620002  34.00  33.00  35.00     12818   4055       7854
# 4       110037   620002  34.00  33.00  35.00      5715   4055       7854
# ...        ...      ...    ...    ...    ...       ...    ...        ...
# 12435   581421   573102  48.10  40.40  38.90      4959   2430      17136
# 12436   580008   591307  68.58  33.02  35.56     17273   2295      16105
# 12437   591307   580008  68.58  33.02  35.56     17273   2295      16105
# 12438   583229   585416  55.00  45.00  41.00     14357   2835      20295
# 12439   585416   583229  55.00  45.00  41.00     14357   2835      20295
#
#        org_state  org_hasMetroCity  org_isSpecialDest  org_po_del  dst_state  \
# 0             29                 1                  0           0         15
# 1              9                 0                  0           1         15
# 2             29                 1                  0           0         29
# 3              7                 1                  0           0         29
# 4              7                 1                  0           0         29
# ...          ...               ...                ...         ...        ...
# 12435         14                 1                  0           1         14
# 12436         14                 1                  0           0         14
# 12437         14                 1                  0           0         14
# 12438         14                 1                  0           1         14
# 12439         14                 1                  0           1         14
#
#        dst_hasMetroCity  dst_isSpecialDest  dst_po_del     distance
# 0                     0                  0           1   543.049398
# 1                     0                  0           1  1463.002661
# 2                     1                  0           0   296.048421
# 3                     1                  0           0  1978.745116
# 4                     1                  0           0  1978.745116
# ...                 ...                ...         ...          ...
# 12435                 1                  0           1   226.867973
# 12436                 1                  0           0    80.709917
# 12437                 1                  0           0    80.709917
# 12438                 1                  0           1   272.839458
# 12439                 1                  0           1   272.839458
#
# [12440 rows x 17 columns]

# %%
cdf_copy=cdf_copy.drop(cdf_copy.loc[cdf_copy['distance'].isnull()].index)

# %%
cdf_copy.loc[cdf_copy['distance'].isnull()]
# Out:
# Empty DataFrame
# Columns: [org_pin, dst_pin, len, wid, dep, obj_cost, price, charge_wt, org_state, org_hasMetroCity, org_isSpecialDest, org_po_del, dst_state, dst_hasMetroCity, dst_isSpecialDest, dst_po_del, distance]
# Index: []

# %%
corr_matrix = cdf_copy.drop(['price'],axis=1).corr()

# %%
corr_matrix
# Out:
#                     org_pin   dst_pin       len       wid       dep  obj_cost  \
# org_pin            1.000000  0.146755  0.024494  0.026373  0.028240 -0.001546
# dst_pin            0.146755  1.000000  0.023517  0.029654  0.028443  0.002606
# len                0.024494  0.023517  1.000000  0.831674  0.786836 -0.010314
# wid                0.026373  0.029654  0.831674  1.000000  0.723049 -0.014077
# dep                0.028240  0.028443  0.786836  0.723049  1.000000 -0.006611
# obj_cost          -0.001546  0.002606 -0.010314 -0.014077 -0.006611  1.000000
# charge_wt          0.029656  0.029664  0.883570  0.784446  0.879310 -0.005409
# org_state          0.085860  0.086890  0.003020  0.004250  0.011866  0.004392
# org_hasMetroCity   0.084766 -0.123848 -0.006319 -0.002487  0.003187 -0.005281
# org_isSpecialDest  0.203305  0.038754  0.002487 -0.000304  0.003606  0.001372
# org_po_del         0.209357  0.082986  0.014233  0.022875  0.015344 -0.002034
# dst_state          0.085332  0.028545 -0.002851  0.002880  0.000499  0.013567
# dst_hasMetroCity  -0.102656  0.065403 -0.014806 -0.011029 -0.007664 -0.003631
# dst_isSpecialDest  0.034118  0.167099 -0.004073 -0.002530  0.008611  0.000836
# dst_po_del         0.085582  0.193728  0.012634  0.020727  0.011790 -0.007863
# distance           0.057254  0.089183  0.019673  0.026249  0.017341  0.014680
#
#                    charge_wt  org_state  org_hasMetroCity  org_isSpecialDest  \
# org_pin             0.029656   0.085860          0.084766           0.203305
# dst_pin             0.029664   0.086890         -0.123848           0.038754
# len                 0.883570   0.003020         -0.006319           0.002487
# wid                 0.784446   0.004250         -0.002487          -0.000304
# dep                 0.879310   0.011866          0.003187           0.003606
# obj_cost           -0.005409   0.004392         -0.005281           0.001372
# charge_wt           1.000000   0.004963          0.001146           0.007425
# org_state           0.004963   1.000000          0.256342          -0.156138
# org_hasMetroCity    0.001146   0.256342          1.000000          -0.222802
# org_isSpecialDest   0.007425  -0.156138         -0.222802           1.000000
# org_po_del          0.017060   0.035351         -0.090869          -0.022591
# dst_state          -0.002637   0.093604         -0.086630           0.032563
# dst_hasMetroCity   -0.010713  -0.078145          0.127904           0.002692
# dst_isSpecialDest   0.007809   0.033810          0.000899           0.016774
# dst_po_del          0.013547   0.077321         -0.059913          -0.002416
# distance            0.017803   0.048474         -0.172494           0.097874
#
#                    org_po_del  dst_state  dst_hasMetroCity  dst_isSpecialDest  \
# org_pin              0.209357   0.085332         -0.102656           0.034118
# dst_pin              0.082986   0.028545          0.065403           0.167099
# len                  0.014233  -0.002851         -0.014806          -0.004073
# wid                  0.022875   0.002880         -0.011029          -0.002530
# dep                  0.015344   0.000499         -0.007664           0.008611
# obj_cost            -0.002034   0.013567         -0.003631           0.000836
# charge_wt            0.017060  -0.002637         -0.010713           0.007809
# org_state            0.035351   0.093604         -0.078145           0.033810
# org_hasMetroCity    -0.090869  -0.086630          0.127904           0.000899
# org_isSpecialDest   -0.022591   0.032563          0.002692           0.016774
# org_po_del           1.000000   0.069264         -0.036685          -0.005291
# dst_state            0.069264   1.000000          0.289169          -0.215564
# dst_hasMetroCity    -0.036685   0.289169          1.000000          -0.204295
# dst_isSpecialDest   -0.005291  -0.215564         -0.204295           1.000000
# dst_po_del           0.066844   0.065824         -0.138761           0.024248
# distance             0.073360   0.058799         -0.145097           0.087031
#
#                    dst_po_del  distance
# org_pin              0.085582  0.057254
# dst_pin              0.193728  0.089183
# len                  0.012634  0.019673
# wid                  0.020727  0.026249
# dep                  0.011790  0.017341
# obj_cost            -0.007863  0.014680
# charge_wt            0.013547  0.017803
# org_state            0.077321  0.048474
# org_hasMetroCity    -0.059913 -0.172494
# org_isSpecialDest   -0.002416  0.097874
# org_po_del           0.066844  0.073360
# dst_state            0.065824  0.058799
# dst_hasMetroCity    -0.138761 -0.145097
# dst_isSpecialDest    0.024248  0.087031
# dst_po_del           1.000000  0.072735
# distance             0.072735  1.000000

# %%
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_46070/73047246.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#                    org_pin   dst_pin       len       wid       dep  obj_cost  \
# org_pin                NaN  0.146755  0.024494  0.026373  0.028240 -0.001546
# dst_pin                NaN       NaN  0.023517  0.029654  0.028443  0.002606
# len                    NaN       NaN       NaN  0.831674  0.786836 -0.010314
# wid                    NaN       NaN       NaN       NaN  0.723049 -0.014077
# dep                    NaN       NaN       NaN       NaN       NaN -0.006611
# obj_cost               NaN       NaN       NaN       NaN       NaN       NaN
# charge_wt              NaN       NaN       NaN       NaN       NaN       NaN
# org_state              NaN       NaN       NaN       NaN       NaN       NaN
# org_hasMetroCity       NaN       NaN       NaN       NaN       NaN       NaN
# org_isSpecialDest      NaN       NaN       NaN       NaN       NaN       NaN
# org_po_del             NaN       NaN       NaN       NaN       NaN       NaN
# dst_state              NaN       NaN       NaN       NaN       NaN       NaN
# dst_hasMetroCity       NaN       NaN       NaN       NaN       NaN       NaN
# dst_isSpecialDest      NaN       NaN       NaN       NaN       NaN       NaN
# dst_po_del             NaN       NaN       NaN       NaN       NaN       NaN
# distance               NaN       NaN       NaN       NaN       NaN       NaN
#
#                    charge_wt  org_state  org_hasMetroCity  org_isSpecialDest  \
# org_pin             0.029656   0.085860          0.084766           0.203305
# dst_pin             0.029664   0.086890         -0.123848           0.038754
# len                 0.883570   0.003020         -0.006319           0.002487
# wid                 0.784446   0.004250         -0.002487          -0.000304
# dep                 0.879310   0.011866          0.003187           0.003606
# obj_cost           -0.005409   0.004392         -0.005281           0.001372
# charge_wt                NaN   0.004963          0.001146           0.007425
# org_state                NaN        NaN          0.256342          -0.156138
# org_hasMetroCity         NaN        NaN               NaN          -0.222802
# org_isSpecialDest        NaN        NaN               NaN                NaN
# org_po_del               NaN        NaN               NaN                NaN
# dst_state                NaN        NaN               NaN                NaN
# dst_hasMetroCity         NaN        NaN               NaN                NaN
# dst_isSpecialDest        NaN        NaN               NaN                NaN
# dst_po_del               NaN        NaN               NaN                NaN
# distance                 NaN        NaN               NaN                NaN
#
#                    org_po_del  dst_state  dst_hasMetroCity  dst_isSpecialDest  \
# org_pin              0.209357   0.085332         -0.102656           0.034118
# dst_pin              0.082986   0.028545          0.065403           0.167099
# len                  0.014233  -0.002851         -0.014806          -0.004073
# wid                  0.022875   0.002880         -0.011029          -0.002530
# dep                  0.015344   0.000499         -0.007664           0.008611
# obj_cost            -0.002034   0.013567         -0.003631           0.000836
# charge_wt            0.017060  -0.002637         -0.010713           0.007809
# org_state            0.035351   0.093604         -0.078145           0.033810
# org_hasMetroCity    -0.090869  -0.086630          0.127904           0.000899
# org_isSpecialDest   -0.022591   0.032563          0.002692           0.016774
# org_po_del                NaN   0.069264         -0.036685          -0.005291
# dst_state                 NaN        NaN          0.289169          -0.215564
# dst_hasMetroCity          NaN        NaN               NaN          -0.204295
# dst_isSpecialDest         NaN        NaN               NaN                NaN
# dst_po_del                NaN        NaN               NaN                NaN
# distance                  NaN        NaN               NaN                NaN
#
#                    dst_po_del  distance
# org_pin              0.085582  0.057254
# dst_pin              0.193728  0.089183
# len                  0.012634  0.019673
# wid                  0.020727  0.026249
# dep                  0.011790  0.017341
# obj_cost            -0.007863  0.014680
# charge_wt            0.013547  0.017803
# org_state            0.077321  0.048474
# org_hasMetroCity    -0.059913 -0.172494
# org_isSpecialDest   -0.002416  0.097874
# org_po_del           0.066844  0.073360
# dst_state            0.065824  0.058799
# dst_hasMetroCity    -0.138761 -0.145097
# dst_isSpecialDest    0.024248  0.087031
# dst_po_del                NaN  0.072735
# distance                  NaN       NaN

# %%
to_drop = [column for column in upper.columns if any(upper[column] > 0.9)]
to_drop
# Out:
# []

# %%
cdf_copy.drop(['len','wid','dep'],inplace=True,axis=1)

# %%
corr_matrix = cdf_copy.drop(['price'],axis=1).corr()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
# /var/folders/bn/w9w3gf013z3cdsvwbs4y84900000gn/T/ipykernel_46070/3055589898.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
#                    org_pin   dst_pin  obj_cost  charge_wt  org_state  \
# org_pin                NaN  0.146755 -0.001546   0.029656   0.085860
# dst_pin                NaN       NaN  0.002606   0.029664   0.086890
# obj_cost               NaN       NaN       NaN  -0.005409   0.004392
# charge_wt              NaN       NaN       NaN        NaN   0.004963
# org_state              NaN       NaN       NaN        NaN        NaN
# org_hasMetroCity       NaN       NaN       NaN        NaN        NaN
# org_isSpecialDest      NaN       NaN       NaN        NaN        NaN
# org_po_del             NaN       NaN       NaN        NaN        NaN
# dst_state              NaN       NaN       NaN        NaN        NaN
# dst_hasMetroCity       NaN       NaN       NaN        NaN        NaN
# dst_isSpecialDest      NaN       NaN       NaN        NaN        NaN
# dst_po_del             NaN       NaN       NaN        NaN        NaN
# distance               NaN       NaN       NaN        NaN        NaN
#
#                    org_hasMetroCity  org_isSpecialDest  org_po_del  dst_state  \
# org_pin                    0.084766           0.203305    0.209357   0.085332
# dst_pin                   -0.123848           0.038754    0.082986   0.028545
# obj_cost                  -0.005281           0.001372   -0.002034   0.013567
# charge_wt                  0.001146           0.007425    0.017060  -0.002637
# org_state                  0.256342          -0.156138    0.035351   0.093604
# org_hasMetroCity                NaN          -0.222802   -0.090869  -0.086630
# org_isSpecialDest               NaN                NaN   -0.022591   0.032563
# org_po_del                      NaN                NaN         NaN   0.069264
# dst_state                       NaN                NaN         NaN        NaN
# dst_hasMetroCity                NaN                NaN         NaN        NaN
# dst_isSpecialDest               NaN                NaN         NaN        NaN
# dst_po_del                      NaN                NaN         NaN        NaN
# distance                        NaN                NaN         NaN        NaN
#
#                    dst_hasMetroCity  dst_isSpecialDest  dst_po_del  distance
# org_pin                   -0.102656           0.034118    0.085582  0.057254
# dst_pin                    0.065403           0.167099    0.193728  0.089183
# obj_cost                  -0.003631           0.000836   -0.007863  0.014680
# charge_wt                 -0.010713           0.007809    0.013547  0.017803
# org_state                 -0.078145           0.033810    0.077321  0.048474
# org_hasMetroCity           0.127904           0.000899   -0.059913 -0.172494
# org_isSpecialDest          0.002692           0.016774   -0.002416  0.097874
# org_po_del                -0.036685          -0.005291    0.066844  0.073360
# dst_state                  0.289169          -0.215564    0.065824  0.058799
# dst_hasMetroCity                NaN          -0.204295   -0.138761 -0.145097
# dst_isSpecialDest               NaN                NaN    0.024248  0.087031
# dst_po_del                      NaN                NaN         NaN  0.072735
# distance                        NaN                NaN         NaN       NaN

# %%
to_drop = [column for column in upper.columns if any(upper[column] > 0.9)]
to_drop
# Out:
# []

# %%
for x in cdf_copy.columns.values:
    print(cdf[x].isnull().values.any())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
cdf_copy[cdf_copy['distance'].isnull()]
# Out:
# Empty DataFrame
# Columns: [org_pin, dst_pin, obj_cost, price, charge_wt, org_state, org_hasMetroCity, org_isSpecialDest, org_po_del, dst_state, dst_hasMetroCity, dst_isSpecialDest, dst_po_del, distance]
# Index: []

# %%
Train = cdf_copy.sample(frac=1, random_state=12).reset_index(drop=True)
# Independent and Dependent Variables
x = Train.drop('price',axis=1)
y = Train['price']

# %%
x
# Out:
#        org_pin  dst_pin  obj_cost  charge_wt  org_state  org_hasMetroCity  \
# 0       225305   303505     18763       1347         34                 0
# 1       685533   630211     19983       1041         15                 0
# 2       193401   695017      8562        380         12                 0
# 3       395010   781015     22224       1800          9                 0
# 4       110018   752070     13063       3138          7                 1
# ...        ...      ...       ...        ...        ...               ...
# 12435   576226   583116      1383        379         14                 1
# 12436   755008   743330     18753       1800         24                 0
# 12437   110055   110071     13293       6363          7                 1
# 12438   600097   517419      4836      16105         29                 1
# 12439   121009   160006     24352       6595         10                 0
#
#        org_isSpecialDest  org_po_del  dst_state  dst_hasMetroCity  \
# 0                      0           1         27                 0
# 1                      0           1         29                 1
# 2                      1           1         15                 0
# 3                      0           1          3                 0
# 4                      0           0         24                 0
# ...                  ...         ...        ...               ...
# 12435                  0           1         14                 1
# 12436                  0           1         35                 1
# 12437                  0           0          7                 1
# 12438                  0           0          1                 0
# 12439                  0           1          5                 0
#
#        dst_isSpecialDest  dst_po_del     distance
# 0                      0           1   423.511478
# 1                      0           0   170.705679
# 2                      0           1  2851.999162
# 3                      1           1  1981.273677
# 4                      0           1  1249.030926
# ...                  ...         ...          ...
# 12435                  0           1   309.613022
# 12436                  0           1   303.385805
# 12437                  0           0    16.526234
# 12438                  0           1   120.841617
# 12439                  0           1   255.731193
#
# [12440 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=12)

# %%
x_train.columns
# Out:
# Index(['org_pin', 'dst_pin', 'obj_cost', 'charge_wt', 'org_state',
#        'org_hasMetroCity', 'org_isSpecialDest', 'org_po_del', 'dst_state',
#        'dst_hasMetroCity', 'dst_isSpecialDest', 'dst_po_del', 'distance'],
#       dtype='object')

# %%
def test_accuracy(models):
    for i in models:
        i.fit(x_train,np.log(y_train))
        pred=pd.Series(i.predict(x_test)).abs()
        print("{}:{}".format(i,mean_squared_log_error(y_test, np.exp(pred))))

# %%
from sklearn.metrics import mean_squared_log_error
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

# %%
ran=RandomForestRegressor(n_jobs=-1)
grad=GradientBoostingRegressor()
xgb=XGBRegressor()
lgb=LGBMRegressor()
cat=CatBoostRegressor(verbose=200)

# %%
models=[xgb, ran, lgb, grad, cat]
test_accuracy(models)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...):0.006089929774559143
# RandomForestRegressor(n_jobs=-1):0.014917131539571483
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000329 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1351
# [LightGBM] [Info] Number of data points in the train set: 9952, number of used features: 13
# [LightGBM] [Info] Start training from score 7.055597
# LGBMRegressor():0.008226107401136004
# GradientBoostingRegressor():0.021162853547077098
# Learning rate set to 0.058864
# 0:	learn: 0.9852699	total: 2.32ms	remaining: 2.32s
# 200:	learn: 0.0979120	total: 237ms	remaining: 942ms
# 400:	learn: 0.0699743	total: 476ms	remaining: 711ms
# 600:	learn: 0.0581556	total: 713ms	remaining: 474ms
# 800:	learn: 0.0503363	total: 950ms	remaining: 236ms
# 999:	learn: 0.0448178	total: 1.19s	remaining: 0us
# <catboost.core.CatBoostRegressor object at 0x320297850>:0.003664747094825197

# %%
ypred_lgb = pd.Series(lgb.predict(x_test)).abs()
mean_squared_log_error(y_test,np.exp(ypred_lgb))
# Out:
# 0.008226107401136004

# %%
ypred_cat = pd.Series(cat.predict(x_test)).abs()
mean_squared_log_error(y_test,np.exp(ypred_cat))
# Out:
# 0.003664747094825197

# %%
x_test
# Out:
#        org_pin  dst_pin  obj_cost  charge_wt  org_state  org_hasMetroCity  \
# 618     400024   413801     10051       3900         19                 1
# 213     623512   411008     20757        361         29                 1
# 12225   627352   638503     23031       2339         29                 1
# 1783    609811   412411      2816        836         29                 1
# 991     637211   281405      5876        329         29                 1
# ...        ...      ...       ...        ...        ...               ...
# 7488    689584   570026     18580        569         15                 0
# 12079   610101   683101      1870        380         29                 1
# 4244    678001   670582     17135      17920         15                 0
# 1530    591220   583282     17740       1075         14                 1
# 1146    533435   515331      9142       2170          1                 0
#
#        org_isSpecialDest  org_po_del  dst_state  dst_hasMetroCity  \
# 618                    0           1         19                 1
# 213                    0           1         19                 1
# 12225                  0           1         29                 1
# 1783                   0           1         19                 1
# 991                    0           0         34                 0
# ...                  ...         ...        ...               ...
# 7488                   0           1         14                 1
# 12079                  0           1         15                 0
# 4244                   0           0         15                 0
# 1530                   0           1         14                 1
# 1146                   0           1          1                 0
#
#        dst_isSpecialDest  dst_po_del     distance
# 618                    0           0   191.092995
# 213                    0           0  1159.392994
# 12225                  0           1   299.042816
# 1783                   0           1  1084.547430
# 991                    0           1  1791.279370
# ...                  ...         ...          ...
# 7488                   0           1   319.044677
# 12079                  0           0   373.556882
# 4244                   0           1  8070.820906
# 1530                   0           1   207.113288
# 1146                   0           1   612.742659
#
# [2488 rows x 13 columns]

# %%
plt.figure(figsize=(12,8))
lgb.fit(x,np.log(y))
a=zip(x.columns,lgb.feature_importances_)
feat_imp=pd.DataFrame(a)
feat_imp.columns=["feat","imp"]
feat_imp=feat_imp.sort_values(by="imp", ascending=False)
sns.barplot(data=feat_imp, x="imp", y="feat");
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000208 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1351
# [LightGBM] [Info] Number of data points in the train set: 12440, number of used features: 13
# [LightGBM] [Info] Start training from score 7.046545

# %%
yt=y_test.reset_index(drop=True)

# %%
from matplotlib.pyplot import figure
figure(figsize=(10, 10), dpi=80)
plt.plot(yt)
plt.tight_layout()
plt.plot(np.exp(ypred_lgb))

# %%
np.exp(ypred_lgb)
# Out:
# 0        919.477663
# 1        375.842665
# 2        593.666012
# 3        611.885105
# 4        377.803349
#            ...
# 2483     391.649317
# 2484     303.467143
# 2485    3312.559572
# 2486     407.558890
# 2487     701.264041
# Length: 2488, dtype: float64

# %%
from matplotlib.pyplot import figure
figure(figsize=(35, 25), dpi=100)
plt.plot(yt, label="actual")

plt.tight_layout()
plt.plot(np.exp(ypred_cat), label="pred")
plt.legend(loc="upper left")

# %%
# import pickle
# with open('xgbmodel_prem_pred_4.pkl','wb') as f:
#     pickle.dump(lgb,f)

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_true=yt, y_pred=np.exp(ypred_lgb))

# %%
r2
# Out:
# 0.9839466832621726

# %%
((len(x_test)-1)/(len(x_test)-len(x_test.columns)-1))
# Out:
# 1.0052546483427647

# %%
(1-(1-r2_score(y_test, np.exp(ypred_lgb)))*((len(x_test)-1)/(len(x_test)-len(x_test.columns)-1)))
# Out:
# 0.9838623287279803
